# %% [markdown]
# # Atténuation
#
# Voici les résultats qu'on pourra avoir en utilisant le ratio de couverture des secteurs angulaires réels et théoriques pour l'éclairage.
#
# A titre de comparaison, on verra l'effet "niveaux de gris" limités à COLOR_RANGE+1 couleurs différentes par rapport à l'utilisation de l'échelle complète disponible avec le RGB 8 bits.
#
# **[R1 attention]:** il manque certains contrôles de cohérence sur les valeurs des curseurs (graphs interactifs).
#
# **[R1 attention2]:** il y a un **bug** dans l'échantillonnage des niveaux de gris avec certaines valeurs... correction à venir.
#
# **attention3:** Les widgets ne fonctionnent pas avec nbviewer (ou en tout cas je n'ai pas réussi à les faire fonctoinner. Si vous voulez tester ça sur votre propre serveur Jupyter, passez la valeur de **INTERACTIVE** à **True** dans la première ligne du code de la cellule suivante.
#
# ## 1. Initialisation

# %%
INTERACTIVE = False

# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML

# NOTE: array[y, x]
print("Imports: OK...")
# Out:
# Imports: OK...

# %%
# Constants
# size of arrays
WIDTH = 10
HEIGHT = 10

# if abs(a - b) < EPSILON then a == b
EPSILON = 0.1
# For approximation
ROUNDING_POSITION = 3

# Constants
# COLOR_RANGE+1 shades of grey
COLOR_RANGE = 10
COLOR_MIN = 40
COLOR_MAX = 200
COLOR_DELTA = int((COLOR_MAX - COLOR_MIN) / COLOR_RANGE)

# x axis
vx = np.array([1., 0.])

light_angles = np.array([-180., 180.])

# Display Array, descending y axis
def dumpdata(msg, data):
    print(f"## {msg} ##\n {pd.DataFrame(data).sort_index(ascending=False, axis=0)}\n")

print("Constants and basic functions: OK...")
# Out:
# Constants and basic functions: OK...

# %%
# base angles
base_alpha = np.zeros([HEIGHT, WIDTH])*np.nan
base_alpha_min = np.zeros([HEIGHT, WIDTH])*np.nan
base_alpha_max = np.zeros([HEIGHT, WIDTH])*np.nan

# Compute base angles (vertical walls)
base_alpha_v = np.zeros([HEIGHT, WIDTH])*np.nan
base_alpha_min_v = np.zeros([HEIGHT, WIDTH])*np.nan
base_alpha_max_v = np.zeros([HEIGHT, WIDTH])*np.nan

# Compute base angles (horizontal walls)
base_alpha_h = np.zeros([HEIGHT, WIDTH])*np.nan
base_alpha_min_h = np.zeros([HEIGHT, WIDTH])*np.nan
base_alpha_max_h = np.zeros([HEIGHT, WIDTH])*np.nan

# real angles
real_alpha_min = np.zeros([HEIGHT, WIDTH])*np.nan
real_alpha_max = np.zeros([HEIGHT, WIDTH])*np.nan
real_alpha = np.zeros([HEIGHT, WIDTH])

# [0. ; 1.] ratio = entering light angle / base light angle
# are we receiving all the lighting that we can accept without blocking element?
real_ratio = np.zeros([HEIGHT, WIDTH])

# Blocking blocks
blocks = np.zeros([HEIGHT, WIDTH])

# vibility to color convertion
lighting_color = np.zeros([HEIGHT, WIDTH])

# Light Source L (0.5, 0.5)
L = np.array([0.5, 0.5])

print("Structures: OK")
# Out:
# Structures: OK

# %%
def resetArrays():
    real_alpha_min.fill(np.nan)
    real_alpha_max.fill(np.nan)
    real_alpha.fill(0.)
    real_ratio.fill(0.)
    real_alpha_min[0, 0] = light_angles[0]
    real_alpha_max[0, 0] = light_angles[1]
    real_alpha[0, 0] = light_angles[1] - light_angles[0]
    real_ratio[0, 0] = 1.
    blocks.fill(0.)

# Get the intersection of 2 angles
def intersect(in_min, in_max, th_min, th_max):
    if (in_max < th_min or in_min > th_max):
        # No overlap
        return (0., 0.)
    r_max = min(th_max, in_max)
    r_min = max(th_min, in_min)
    if (r_max - r_min < EPSILON):
        r_max = r_min
    return (r_min, r_max)

# Get the union of 2 angles IF they touch each other
def union(a1_min, a1_max, a2_min, a2_max):
    # One angle is null
    if (a1_min == a1_max == 0):
        return(a2_min, a2_max)
    if (a2_min == a2_max == 0):
        return(a1_min, a1_max)
    # Not neighbors ?
    if (abs(a2_min - a1_max) > EPSILON and abs(a1_min - a2_max) > EPSILON):
        #print(a1_min, a1_max, a2_min, a2_max, abs(a2_min - a1_max))
        print(f"[union] - FATAL - ({x}, {y}) ({a1_min}, {a1_max}) not neighbor of ({a2_min}, {a2_max})")
        return (0., 0.)
    # Union
    return (min(a1_min, a2_min), max(a1_max, a2_max))

def setBaseAlpha(x, y, a, b):
    alpha = np.degrees(np.math.atan2(np.linalg.det([a,b]),np.dot(a,b)))
    beta = np.degrees(np.math.atan2(np.linalg.det([vx, a]), np.dot(vx, a)))
    base_alpha[y, x] = alpha
    base_alpha_min[y, x] = beta
    base_alpha_max[y, x] = beta + alpha

def computeBaseSector():
    # First line
    y = 0
    for x in range(1,WIDTH):
        a = np.array([x, 0]) - L
        b = np.array([x, 1]) - L
        setBaseAlpha(x, y, a, b)
    
    # First Column
    x = 0
    for y in range(1, HEIGHT):
        a = np.array([1, y]) - L
        b = np.array([0, y]) - L
        setBaseAlpha(x, y, a, b)

    # All the other cells
    for y in range(1, HEIGHT):
        for x in range(1, WIDTH):
            a = np.array([x+1, y]) - L
            b = np.array([x, y+1]) - L
            setBaseAlpha(x, y, a, b)

def getAlphaBeta(a, b):
    alpha = np.degrees(np.math.atan2(np.linalg.det([a,b]),np.dot(a,b)))
    beta = np.degrees(np.math.atan2(np.linalg.det([vx, a]), np.dot(vx, a)))
    return(alpha, beta)

def setBaseAlphaH(x, y, a, b):
    (alpha, beta) = getAlphaBeta(a, b)
    base_alpha_h[y, x] = alpha
    base_alpha_min_h[y, x] = beta
    base_alpha_max_h[y, x] = beta + alpha

def setBaseAlphaV(x, y, a, b):
    (alpha, beta) = getAlphaBeta(a, b)
    base_alpha_v[y, x] = alpha
    base_alpha_min_v[y, x] = beta
    base_alpha_max_v[y, x] = beta + alpha

def computeBaseSector_Walls():
    # First line
    y = 0
    for x in range(1,WIDTH):
        a = np.array([x, 0]) - L
        b = np.array([x, 1]) - L
        setBaseAlphaH(x, y, a, a)
        setBaseAlphaV(x, y, a, b)
    
    # First Column
    x = 0
    for y in range(1, HEIGHT):
        a = np.array([1, y]) - L
        b = np.array([0, y]) - L
        setBaseAlphaH(x, y, a, b)
        setBaseAlphaV(x, y, a, a)

    # All the other cells
    for y in range(1, HEIGHT):
        for x in range(1, WIDTH):
            a = np.array([x+1, y]) - L
            b = np.array([x, y]) - L
            setBaseAlphaH(x, y, a, b)
            a = np.array([x, y]) - L
            b = np.array([x, y+1]) - L
            setBaseAlphaV(x, y, a, b)

def setRealAlpha(x, y, a_min, a_max, blocktype=""):
    real_alpha_min[y, x] = a_min
    real_alpha_max[y, x] = a_max
    real_alpha[y, x] = a_max - a_min
    # Watch out for the 1.0 -> 0.9999... 1.0 effect
    if (blocktype=="v"):
        real_ratio[y, x] = round(real_alpha[y, x] / base_alpha_v[y, x], ROUNDING_POSITION)
    elif (blocktype=="h"):
        real_ratio[y, x] = round(real_alpha[y, x] / base_alpha_h[y, x], ROUNDING_POSITION)
    elif (blocktype=="a"):
        real_ratio[y, x] = round((real_ratio[y-1, x] + real_ratio[y, x-1])/2., ROUNDING_POSITION)
    else:
        real_ratio[y, x] = round(real_alpha[y, x] / base_alpha[y, x], ROUNDING_POSITION)
    # with the ratio we know if the blocking cell receive light (obstacle must be displayed)
    if (blocks[y, x] == 1):
        real_alpha[y, x] = 0.
        real_alpha_min[y, x] = 0.
        real_alpha_max[y, x] = 0.
    return(real_alpha_min[y, x], real_alpha_max[y, x])

def computeSector(x, y):
    # Already done
    if (not np.isnan(real_alpha_min[y, x]) and not np.isnan(real_alpha_max[y, x])):
        return (real_alpha_min[y, x], real_alpha_max[y, x])
    # Origin
    if (x == 0 and y == 0):
        return (real_alpha_min[0, 0], real_alpha_max[0, 0])
    # First row (only x-1 is needed)
    if (y == 0):
        prevx = computeSector(x-1, y)
        real = intersect(prevx[0], prevx[1], base_alpha_min[y, x], base_alpha_max[y, x])
        return setRealAlpha(x, y, real[0], real[1])
    # First column (only y-1 is needed)
    if (x == 0):
        prevy = computeSector(x, y-1)
        real = intersect(prevy[0], prevy[1], base_alpha_min[y, x], base_alpha_max[y, x])
        return setRealAlpha(x, y, real[0], real[1])
    # The other cells (x-1 AND y-1 control the flow of light entering this cell)
    else:
        prevx = computeSector(x-1, y)
        prevy = computeSector(x, y-1)
        real = []
        btype = ""
        if (blocks[y, x]==1 and blocks[y, x-1]==1):
            btype="h"
            real = intersect(prevy[0], prevy[1], base_alpha_min_h[y, x], base_alpha_max_h[y, x])
            print(f"({x},{y}) blocks H : real({real[0], real[1]})")
        elif (blocks[y, x]==1 and blocks[y-1, x]==1):
            btype="v"
            real = intersect(prevx[0], prevx[1], base_alpha_min_v[y, x], base_alpha_max_v[y, x])
            print(f"({x},{y}) blocks V : real({real[0], real[1]})")
        else:    
            real = intersect(prevx[0], prevx[1], base_alpha_min[y, x], base_alpha_max[y, x])
            real2 = intersect(prevy[0], prevy[1], base_alpha_min[y, x], base_alpha_max[y, x])
            real = union(real[0], real[1], real2[0], real2[1])
        if (btype!="") :
            if (blocks[y-1, x] == blocks[y, x-1] == 1):
                print(f"({x},{y}) angle")
                btype="a"
        return setRealAlpha(x, y, real[0], real[1], btype)


def convertLightingRatioToColor():
    for y in range(HEIGHT):
        for x in range(WIDTH):
            if (real_ratio[y, x] == 0.):
                lighting_color[y, x] = 0
            else:
                lighting_color[y, x] = int(abs(real_ratio[y, x]) * COLOR_RANGE) * COLOR_DELTA + COLOR_MIN

def color_max_red(value):
    v = int(value)
    hexcolor = '#%02x%02x%02x' % (v, v, v)
    return 'background-color: {}'.format(hexcolor)

def color_block(value):
    return 'font-weight: bold; color: red'

def markBlocks(datastyle):
    for y in range(HEIGHT):
        for x in range(WIDTH):
            if (blocks[y, x]):
                datastyle.applymap(color_block, subset=(y, x))

def fakeDisplay(msg=""):
    df = pd.DataFrame(lighting_color).sort_index(ascending=False, axis=0)
    s = df.style.applymap(color_max_red)
    markBlocks(s)
    if msg!="":
        display(HTML("<b>"+msg+"</b>"))
    display(HTML(s.render()+"</br>"))

print("Functions: OK")
# Out:
# Functions: OK

# %%
computeBaseSector()
computeBaseSector_Walls()
print("Base sectors: OK")
# Out:
# Base sectors: OK

# %% [markdown]
# ### Situation de départ sans aucun obstacle

# %%
resetArrays()

computeSector(WIDTH-1, HEIGHT-1)
convertLightingRatioToColor()

print(f"Light source angles ({light_angles[0]}, {light_angles[1]})\n")
#display("Real Ratio", real_ratio)    
fakeDisplay("Real Ratio to color")
# Out:
# Light source angles (-180.0, 180.0)
# <b>Real Ratio to color</b>
# <style  type="text/css" >
#     #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #c8c8c8;
#         }    #T_e81d56c4_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac

# %% [markdown]
# Calcul des distances Cellule à Source lumineuse

# %%
dist = np.zeros([HEIGHT, WIDTH])
lum = np.zeros([HEIGHT, WIDTH])

def computeBaseDistance():
    for y in range(HEIGHT):
        for x in range (WIDTH):
            a = np.array([x+0.5, y+0.5]) - L
            dist[y, x] = abs(np.linalg.norm([a]))
    # to avoid special case at origin
    dist[0, 0] = 1.

computeBaseDistance()
dumpdata("distances", dist)
# Out:
# ## distances ##
#       0         1         2         3         4          5          6  \
# 9  9.0  9.055385  9.219544  9.486833  9.848858  10.295630  10.816654
# 8  8.0  8.062258  8.246211  8.544004  8.944272   9.433981  10.000000
# 7  7.0  7.071068  7.280110  7.615773  8.062258   8.602325   9.219544
# 6  6.0  6.082763  6.324555  6.708204  7.211103   7.810250   8.485281
# 5  5.0  5.099020  5.385165  5.830952  6.403124   7.071068   7.810250
# 4  4.0  4.123106  4.472136  5.000000  5.656854   6.403124   7.211103
# 3  3.0  3.162278  3.605551  4.242641  5.000000   5.830952   6.708204
# 2  2.0  2.236068  2.828427  3.605551  4.472136   5.385165   6.324555
# 1  1.0  1.414214  2.236068  3.162278  4.123106   5.099020   6.082763
# 0  1.0  1.000000  2.000000  3.000000  4.000000   5.000000   6.000000
#
#            7          8          9
# 9  11.401754  12.041595  12.727922
# 8  10.630146  11.313708  12.041595
# 7   9.899495  10.630146  11.401754
# 6   9.219544  10.000000  10.816654
# 5   8.602325   9.433981  10.295630
# 4   8.062258   8.944272   9.848858
# 3   7.615773   8.544004   9.486833
# 2   7.280110   8.246211   9.219544
# 1   7.071068   8.062258   9.055385
# 0   7.000000   8.000000   9.000000

# %% [markdown]
# ## 2. Atténuation quadratique
#
# ### 2.1 quadratique pure

# %%
lum = np.zeros([HEIGHT, WIDTH])

# 1/d^2 falloff
def computeLighting_d2falloff():
    for y in range(HEIGHT):
        for x in range (WIDTH):
            lum[y, x] = real_ratio[y, x] / (dist[y, x]*dist[y, x])

def convertRatioToColor(source):
    for y in range(HEIGHT):
        for x in range(WIDTH):
            if (source[y, x] == 0.):
                lighting_color[y, x] = 0
            else:
                lighting_color[y, x] = int(abs(source[y, x]) * COLOR_RANGE) * COLOR_DELTA + COLOR_MIN

def convertRatioToRGB(source):
    for y in range(HEIGHT):
        for x in range(WIDTH):
            if (source[y, x] == 0.):
                lighting_color[y, x] = 0
            else:
                lighting_color[y, x] = int(abs(source[y, x]) * 255)

def fakeDisplay2():
    df = pd.DataFrame(lighting_color).sort_index(ascending=False, axis=0)
    s = df.style.applymap(color_max_red)
    markBlocks(s)
#    dumpdata("blocks", blocks)
    return(df)

resetArrays()
computeSector(WIDTH-1, HEIGHT-1)

computeLighting_d2falloff()
dumpdata("lum", lum)

convertRatioToColor(lum)
fakeDisplay("pure quadratic falloff")

convertRatioToRGB(lum)
fakeDisplay("pure quadratic falloff (RGB)")
# Out:
# ## lum ##
#            0         1         2         3         4         5         6  \
# 9  0.012346  0.012195  0.011765  0.011111  0.010309  0.009434  0.008547
# 8  0.015625  0.015385  0.014706  0.013699  0.012500  0.011236  0.010000
# 7  0.020408  0.020000  0.018868  0.017241  0.015385  0.013514  0.011765
# 6  0.027778  0.027027  0.025000  0.022222  0.019231  0.016393  0.013889
# 5  0.040000  0.038462  0.034483  0.029412  0.024390  0.020000  0.016393
# 4  0.062500  0.058824  0.050000  0.040000  0.031250  0.024390  0.019231
# 3  0.111111  0.100000  0.076923  0.055556  0.040000  0.029412  0.022222
# 2  0.250000  0.200000  0.125000  0.076923  0.050000  0.034483  0.025000
# 1  1.000000  0.500000  0.200000  0.100000  0.058824  0.038462  0.027027
# 0  1.000000  1.000000  0.250000  0.111111  0.062500  0.040000  0.027778
#
#           7         8         9
# 9  0.007692  0.006897  0.006173
# 8  0.008850  0.007812  0.006897
# 7  0.010204  0.008850  0.007692
# 6  0.011765  0.010000  0.008547
# 5  0.013514  0.011236  0.009434
# 4  0.015385  0.012500  0.010309
# 3  0.017241  0.013699  0.011111
# 2  0.018868  0.014706  0.011765
# 1  0.020000  0.015385  0.012195
# 0  0.020408  0.015625  0.012346
# <b>pure quadratic falloff</b>
# <style  type="text/css" >
#     #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #383838;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #484848;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #383838;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #383838;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #282828;
#         }    #T_e8402c44_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac
# <b>pure quadratic falloff (RGB)</b>
# <style  type="text/css" >
#     #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #010101;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #010101;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #010101;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #010101;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #010101;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #050505;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #050505;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #040404;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #040404;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #010101;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #070707;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #060606;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #060606;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #050505;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #040404;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #040404;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #0a0a0a;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #090909;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #080808;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #070707;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #060606;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #050505;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #040404;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #0f0f0f;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #0f0f0f;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #0c0c0c;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #0a0a0a;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #070707;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #060606;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #040404;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #1c1c1c;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #191919;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #131313;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #0e0e0e;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #0a0a0a;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #070707;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #050505;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #040404;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #030303;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #020202;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #3f3f3f;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #323232;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #1f1f1f;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #131313;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #0c0c0c;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #080808;
#         }    #T_e85368ae_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac

# %% [markdown]
# #### constatations :
#
# - l'atténuation est _très_ rapide
# - la zone à la limite du visible est très étendue et il faudra la limiter au passage à la version "discrète" avec n niveaux de gris
# - il faudrait répartir les niveaux de gris de manière non linéaire pour s'adapter à la perception humaine et privilégier les ombres (attention à la correction gamma)
#
# ### 2.2 quadratique avec constante et limite

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

print("interact: OK")
# Out:
# interact: OK

# %%
# k/d^2 falloff + max clamp
def computeLighting_d2falloff_kclamp(k=5):
    for y in range(HEIGHT):
        for x in range (WIDTH):
            lum[y, x] = min(k*(real_ratio[y, x] / (dist[y, x]*dist[y, x])), 1.)

def proceed(k):
    computeLighting_d2falloff_kclamp(k)
    #display("lum", lum)
    convertRatioToColor(lum)
    fakeDisplay(f"quadratic falloff with constant k={k} and limit")
    
    convertRatioToRGB(lum)
    fakeDisplay(f"quadratic falloff with constant k={k} and limit (RGB)")    
    
resetArrays()
computeSector(WIDTH-1, HEIGHT-1)

if INTERACTIVE:
    interact(proceed, k=widgets.FloatSlider(min=0.5,max=50.,step=0.5,value=5.));    
else:
    k = 7.
    proceed(k)
# Out:
# <b>quadratic falloff with constant k=7.0 and limit</b>
# <style  type="text/css" >
#     #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #686868;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #686868;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #585858;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #989898;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #888888;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #787878;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #585858;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #383838;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #282828;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #a8a8a8;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #787878;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #585858;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #484848;
#         }    #T_e8713f0a_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac
# <b>quadratic falloff with constant k=7.0 and limit (RGB)</b>
# <style  type="text/css" >
#     #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #161616;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #151515;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #151515;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #131313;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #121212;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #101010;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #0f0f0f;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #0d0d0d;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #0c0c0c;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #0b0b0b;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #1b1b1b;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #1b1b1b;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #1a1a1a;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #181818;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #161616;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #141414;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #111111;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #0f0f0f;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #0d0d0d;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #0c0c0c;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #242424;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #232323;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #212121;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #1e1e1e;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #1b1b1b;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #181818;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #151515;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #121212;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #0f0f0f;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #0d0d0d;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #313131;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #303030;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #2c2c2c;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #272727;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #222222;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #1d1d1d;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #181818;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #151515;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #111111;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #0f0f0f;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #474747;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #444444;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #3d3d3d;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #343434;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #2b2b2b;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #232323;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #1d1d1d;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #181818;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #141414;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #101010;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #6f6f6f;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #696969;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #595959;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #474747;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #373737;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #2b2b2b;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #222222;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #1b1b1b;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #161616;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #121212;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #c6c6c6;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #b2b2b2;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #898989;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #636363;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #474747;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #343434;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #272727;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #1e1e1e;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #181818;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #131313;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #ffffff;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #ffffff;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #dfdfdf;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #898989;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #595959;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #3d3d3d;
#         }    #T_e87c0430_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac

# %% [markdown]
# #### Avec des obstacles

# %%
resetArrays()

blocks[3, 2] = 1
blocks[2, 3] = 1
blocks[3, 3] = 1

blocks[0, 4] = 1

computeSector(WIDTH-1, HEIGHT-1)

if INTERACTIVE:
    interact(proceed, k=widgets.FloatSlider(min=0.5,max=50.,step=0.5,value=5.));
else:
    k = 7.
    proceed(k)
# Out:
# (3,3) blocks H : real((0.0, 0.0))
# (3,3) angle
# <b>quadratic falloff with constant k=7.0 and limit</b>
# <style  type="text/css" >
#     #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #484848;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #484848;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #383838;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #686868;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #686868;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #989898;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #888888;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #787878;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #585858;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #000000;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #282828;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #c8c8c8;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #a8a8a8;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #787878;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e895d658_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #282828;
#         }
# <b>quadratic falloff with constant k=7.0 and limit (RGB)</b>
# <style  type="text/css" >
#     #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #161616;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #151515;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #151515;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #131313;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #070707;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #1b1b1b;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #1b1b1b;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #1a1a1a;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #131313;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #020202;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #242424;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #232323;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #212121;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #0e0e0e;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #313131;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #303030;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #272727;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #070707;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #474747;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #444444;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #232323;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #6f6f6f;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #696969;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #181818;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #020202;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #070707;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #c6c6c6;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #b2b2b2;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #898989;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #636363;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #000000;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #070707;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #0e0e0e;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #131313;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #131313;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #ffffff;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #ffffff;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #dfdfdf;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #898989;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e8aaf7ea_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #181818;
#         }

# %% [markdown]
# ### 2.3 quadratique et diamètre min/max

# %%
# k/d^2 falloff + max clamp
def computeLighting_quadfalloff_minmaxradius(rmin=2, rmax=3):
    delta = (rmax - rmin)
    for y in range(HEIGHT):
        for x in range (WIDTH):
            if dist[y, x] <= rmin:
                lum[y, x] = real_ratio[y, x]
            else:
                vx = dist[y, x] - rmin
                if vx < delta:
                    lum[y, x] = max(real_ratio[y, x] * ((vx/delta -1)*(vx/delta -1)), 0.)
                else:
                    lum[y, x] = 0.
                
                
def proceed(rmin, rmax):
    computeLighting_quadfalloff_minmaxradius(rmin, rmax)
    convertRatioToColor(lum)
    fakeDisplay(f"max with distance in [0, rmin={rmin}] and quadratic falloff in ]rmin={rmin}, rmax={rmax}]")
    
    convertRatioToRGB(lum)
    fakeDisplay(f"max with distance in [0, rmin={rmin}] and quadratic falloff in ]rmin={rmin}, rmax={rmax}] (RGB)")    

wrmin, wrmax = widgets.FloatSlider(min=2.,max=10.,step=0.5,value=2.),\
                widgets.FloatSlider(min=3.,max=10.,step=0.5,value=7.5)

def update_rmax_range(*args):
    wrmax.min = wrmin.value + 0.5

resetArrays()
computeSector(WIDTH-1, HEIGHT-1)

if INTERACTIVE:
    wrmin.observe(update_rmax_range, 'value')
    interact(proceed, rmin=wrmin, rmax=wrmax)
else:
    rmin=2
    rmax=7.5
    proceed(rmin, rmax)
# Out:
# <b>max with distance in [0, rmin=2] and quadratic falloff in ]rmin=2, rmax=7.5]</b>
# <style  type="text/css" >
#     #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #484848;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #383838;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #383838;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #686868;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #585858;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #585858;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #484848;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #383838;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #888888;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #888888;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #787878;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #585858;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #484848;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #282828;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #000000;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #b8b8b8;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #989898;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #787878;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #585858;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #383838;
#         }    #T_e8c3c70c_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac
# <b>max with distance in [0, rmin=2] and quadratic falloff in ]rmin=2, rmax=7.5] (RGB)</b>
# <style  type="text/css" >
#     #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #020202;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #010101;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #121212;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #101010;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #0b0b0b;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #050505;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #343434;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #303030;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #252525;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #171717;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #0a0a0a;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #010101;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #676767;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #606060;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #4d4d4d;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #343434;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #1c1c1c;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #0a0a0a;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #aaaaaa;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #9e9e9e;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #7f7f7f;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #595959;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #343434;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #171717;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #050505;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #000000;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #ffffff;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #e9e9e9;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #b7b7b7;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #7f7f7f;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #4d4d4d;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #252525;
#         }    #T_e8d32152_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac

# %% [markdown]
# #### Avec des obstacles

# %%
resetArrays()

blocks[3, 2] = 1
blocks[2, 3] = 1
blocks[3, 3] = 1

blocks[0, 4] = 1

computeSector(WIDTH-1, HEIGHT-1)

if INTERACTIVE:
    interact(proceed, rmin=wrmin, rmax=wrmax)
else:
    rmin=2.
    rmax=7.5
    proceed(rmin, rmax)
# Out:
# (3,3) blocks H : real((0.0, 0.0))
# (3,3) angle
# <b>max with distance in [0, rmin=2.0] and quadratic falloff in ]rmin=2.0, rmax=7.5]</b>
# <style  type="text/css" >
#     #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #484848;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #383838;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #686868;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #585858;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #888888;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #888888;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #787878;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #585858;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #282828;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #000000;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #b8b8b8;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #989898;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #787878;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e8ee810e_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #282828;
#         }
# <b>max with distance in [0, rmin=2.0] and quadratic falloff in ]rmin=2.0, rmax=7.5] (RGB)</b>
# <style  type="text/css" >
#     #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #020202;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #010101;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #121212;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #101010;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #0a0a0a;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #343434;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #303030;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #151515;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #676767;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #606060;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #151515;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #aaaaaa;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #9e9e9e;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #7f7f7f;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #595959;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #000000;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #ffffff;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #e9e9e9;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #b7b7b7;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #7f7f7f;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e903249c_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #151515;
#         }

# %% [markdown]
# ## 3. Atténuation linéaire et diamètre min/max

# %%
resetArrays()
computeSector(WIDTH-1, HEIGHT-1)

# k/d^2 falloff + max clamp
def computeLighting_linfalloff_minmaxradius(rmin=2, rmax=3):
    delta = abs(rmax - rmin)
    for y in range(HEIGHT):
        for x in range (WIDTH):
            if dist[y, x] <= rmin:
                lum[y, x] = real_ratio[y, x]
            else:
                lum[y, x] = max(real_ratio[y, x] - ( (real_ratio[y, x]/delta) * (dist[y, x] - rmin)), 0.)

def proceed(rmin, rmax):
    computeLighting_linfalloff_minmaxradius(rmin, rmax)
    convertRatioToColor(lum)
    fakeDisplay(f"max with distance in [0, rmin={rmin}] and linear falloff in ]rmin={rmin}, rmax={rmax}]")
    convertRatioToRGB(lum)
    fakeDisplay(f"max with distance in [0, rmin={rmin}] and linear falloff in ]rmin={rmin}, rmax={rmax}]")

wrmin, wrmax = widgets.FloatSlider(min=2.,max=10.,step=0.5,value=2.),\
                widgets.FloatSlider(min=3.,max=10.,step=0.5,value=7.5)

def update_rmax_range(*args):
    wrmax.min = wrmin.value + 0.5

resetArrays()
computeSector(WIDTH-1, HEIGHT-1)

if INTERACTIVE:
    wrmin.observe(update_rmax_range, 'value')
    interact(proceed, rmin=wrmin, rmax=wrmax)
else:
    rmin=2.
    rmax=7.5
    proceed(rmin, rmax)
# Out:
# <b>max with distance in [0, rmin=2.0] and linear falloff in ]rmin=2.0, rmax=7.5]</b>
# <style  type="text/css" >
#     #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #282828;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #282828;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #282828;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #484848;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #484848;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #484848;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #383838;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #282828;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #686868;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #686868;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #585858;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #585858;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #383838;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #282828;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #888888;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #888888;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #787878;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #686868;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #585858;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #383838;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #282828;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #a8a8a8;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #989898;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #989898;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #787878;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #686868;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #585858;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #383838;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #000000;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #b8b8b8;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #a8a8a8;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #989898;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #787878;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #585858;
#         }    #T_e91de048_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac
# <b>max with distance in [0, rmin=2.0] and linear falloff in ]rmin=2.0, rmax=7.5]</b>
# <style  type="text/css" >
#     #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #171717;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #131313;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #0a0a0a;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #454545;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #414141;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #363636;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #242424;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #0d0d0d;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #737373;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #6f6f6f;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #626262;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #4d4d4d;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #323232;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #131313;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #a2a2a2;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #9c9c9c;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #8c8c8c;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #737373;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #555555;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #323232;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #0d0d0d;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #d0d0d0;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #c9c9c9;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #b4b4b4;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #979797;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #737373;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #4d4d4d;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #242424;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #000000;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #ffffff;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #f4f4f4;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #d8d8d8;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #b4b4b4;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #8c8c8c;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow7_col5 {
#             background-color:  #626262;
#         }    #T_e92cb1ae_e659_11e8_af13_0023249f4e9erow7_col6 {
#             bac

# %%
resetArrays()

blocks[3, 2] = 1
blocks[2, 3] = 1
blocks[3, 3] = 1

blocks[0, 4] = 1

computeSector(WIDTH-1, HEIGHT-1)

if INTERACTIVE:
    interact(proceed, rmin=wrmin, rmax=wrmax)
else:
    rmin = 2.
    rmax = 7.5
    proceed(rmin, rmax)
# Out:
# (3,3) blocks H : real((0.0, 0.0))
# (3,3) angle
# <b>max with distance in [0, rmin=2.0] and linear falloff in ]rmin=2.0, rmax=7.5]</b>
# <style  type="text/css" >
#     #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #282828;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #282828;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #282828;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #484848;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #484848;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #383838;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #282828;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #686868;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #686868;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #484848;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #888888;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #888888;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #383838;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #a8a8a8;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #989898;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #989898;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #787878;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #282828;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #000000;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #c8c8c8;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #b8b8b8;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #a8a8a8;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #989898;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e9457f5e_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #383838;
#         }
# <b>max with distance in [0, rmin=2.0] and linear falloff in ]rmin=2.0, rmax=7.5]</b>
# <style  type="text/css" >
#     #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col0 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col1 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col2 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col3 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col4 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col5 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col6 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col7 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col8 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow0_col9 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col0 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col1 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col2 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col3 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col4 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col5 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col6 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col7 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col8 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow1_col9 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col0 {
#             background-color:  #171717;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col1 {
#             background-color:  #131313;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col2 {
#             background-color:  #0a0a0a;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col3 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col4 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col5 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col6 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col7 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col8 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow2_col9 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col0 {
#             background-color:  #454545;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col1 {
#             background-color:  #414141;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col2 {
#             background-color:  #303030;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col3 {
#             background-color:  #060606;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col4 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col5 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col6 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col7 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col8 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow3_col9 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col0 {
#             background-color:  #737373;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col1 {
#             background-color:  #6f6f6f;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col2 {
#             background-color:  #383838;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col3 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col4 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col5 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col6 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col7 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col8 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow4_col9 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col0 {
#             background-color:  #a2a2a2;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col1 {
#             background-color:  #9c9c9c;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col2 {
#             background-color:  #272727;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col3 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col4 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col5 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col6 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col7 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col8 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow5_col9 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col0 {
#             background-color:  #d0d0d0;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col1 {
#             background-color:  #c9c9c9;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col2 {
#             background-color:  #b4b4b4;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col3 {
#             background-color:  #979797;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col4 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col5 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col6 {
#             background-color:  #060606;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col7 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col8 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow6_col9 {
#             background-color:  #000000;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow7_col0 {
#             background-color:  #ffffff;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow7_col1 {
#             background-color:  #f4f4f4;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow7_col2 {
#             background-color:  #d8d8d8;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow7_col3 {
#             background-color:  #b4b4b4;
#             font-weight:  bold;
#              color:  red;
#         }    #T_e958cbea_e659_11e8_af13_0023249f4e9erow7_col4 {
#             background-color:  #272727;
#         }
