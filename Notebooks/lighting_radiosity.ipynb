# %% [markdown]
# # Résolution Radiosité
#
# Cette partie qui concerne la résolution du système d'équation est très directe. L'algorithme suivi est :
#
# - trouver la surface i pour laquelle la radiosité qui "reste à émettre" (unshot) AiBi est la plus forte (c'est elle qui contribuera le plus à l'éclairage de la scène)
# - pour toutes les autres surface j
#     - mettre à jour ce qui est reçu en fonction de ce qui est émis par i et du facteur de forme
# - et boucler jusqu'à ce qu'on atteigne un état d'équilibre
#
# ## Imports
#
# Note: retour de pandas pour un affichage final

# %%
import numpy as np
import random

# Representation
import pandas as pd
from IPython.display import display, HTML
print("imports: OK")

rng = random.SystemRandom()
print("random generator: OK")
# Out:
# imports: OK
# random generator: OK

# %%
DEFAULT_RHO = 0.55
print(f"default reflectance rho value = {DEFAULT_RHO}")
# Out:
# default reflectance rho value = 0.55

# %% [markdown]
# ## Affichage

# %%
# Display Array, descending y axis
def dumpdata(msg, data):
    print(f"## {msg} ##\n {pd.DataFrame(data).sort_index(ascending=False, axis=0)}\n")

def color_max_red(value):
    v = int(value)
    hexcolor = '#%02x%02x%02x' % (v, v, v)
    return 'background-color: {}'.format(hexcolor)

def convertRatioToRGB(source):
    for y in range(HEIGHT):
        for x in range(WIDTH):
            if (source[y, x] == 0.):
                lighting_color[y, x] = 0
            else:
                lighting_color[y, x] = int(abs(source[y, x]) * 255)
                
def fakeDisplay(msg="", style=True):
    df = pd.DataFrame(lighting_color).sort_index(ascending=False, axis=0)
    
    if style:
        s = df.style.applymap(color_max_red)
    else:
        s = df.style
    if msg!="":
        display(HTML("<b>"+msg+"</b>"))
    display(HTML(s.render()+"</br>"))

# %% [markdown]
# ## Surface
#
# Les modifications :
#
# - dans le constructeur
#     - un changement cosmétique sur l'aquisition de l'identifiant
#     - ρ : l'indice de diffusion de la surface
#     - E : l'éclairement
#     - B : la radiosité (exitance)
#     - dB (ΔB) : la partie non encore émise de la radiosité associée à la surface
# - un moyen de fixer E, B et dB après la création de l'objet
#
# La réflectance rho est fixé à 0.8 par défaut

# %%
class Rect():
    count = -1

    def next():
        Rect.count += 1
        return Rect.count

    def __init__(self, cmin, cmax, norm, rho=DEFAULT_RHO, E=0.):
        self.idt = Rect.next()
        
        # Radiosity
        self.rho = rho
        self.E = E
        self.B = E
        self.dB = E

        # Geometry
        self.cmin = cmin
        self.cmax = cmax
        self.norm = norm
        self.lx = cmax[0] - cmin[0]
        self.ly = cmax[1] - cmin[1]
        self.lz = cmax[2] - cmin[2]
        self.area = self.lx*self.ly + self.lx*self.lz + self.ly*self.lz

        # Patchs
        self.split(0.5,0.5,0.5)
        print(f"{self.idt} {self.cmin} {self.cmax} area:{self.area}")

    def initLightSource(self, E, rho=0.):
        self.E = E
        self.B = E
        self.dB = E
        self.rho = rho
    
    def resetRadiosity(self, rho=DEFAULT_RHO):
        self.B = self.E
        self.dE = self.E
        self.rho = rho


    def getRndUV(self, umin, umax, vmin, vmax):
        # TODO: p have to be in ]0;1[ to avoid the r = 0 case (in Ri T Rj)
        pu = rng.uniform(umin, umax)
        pv = rng.uniform(vmin, vmax)
        #print(f"[get2Rnd] u({umin},{umax}) v({vmin}, {vmax}) {pu}, {pv}")
        return (pu, pv)

    def getRandomPoint(self):
        if (self.lz == 0):
            # R xOy
            (px, py) = self.getRndUV(self.cmin[0], self.cmax[0], self.cmin[1], self.cmax[1])
            pz = self.cmin[2]
        elif (self.ly == 0):
            # R xOz
            (px, pz) = self.getRndUV(self.cmin[0], self.cmax[0], self.cmin[2], self.cmax[2])
            py = self.cmin[1]
        else:
            # R yOz
            (py, pz) = self.getRndUV(self.cmin[1], self.cmax[1], self.cmin[2], self.cmax[2])
            px = self.cmin[0]
        #print(f"(idt:{self.idt} return point ({px}, {py}, {pz})");
        return(np.array([px, py, pz]))

    def getPatchs(self):
        return self.patch

    def split(self, dx=0.5, dy=0.5, dz=0.5):
        self.patch = []

        # Hack to ensure we do at least 1 iteration
        lx = dx  if self.lx == 0 else self.lx
        ly = dy  if self.ly == 0 else self.ly
        lz = dz  if self.lz == 0 else self.lz

        # used to cancel splits on u, v, w
        kx = 0. if lx < 1. else 1.
        ky = 0. if ly < 1. else 1.
        kz = 0. if lz < 1. else 1.

        x0 = self.cmin[0]
        y0 = self.cmin[1]
        z0 = self.cmin[2]

        z = dz / 2.
        while z < lz:
            y = dy / 2.
            while y < ly:
                x = dx / 2.
                while x < lx:
                    #print(f"{x0+x*kx}, {y0+y*ky}, {z0+z*kz}")
                    self.patch.append(np.array([x0+x*kx, y0+y*ky, z0+z*kz]))
                    x += dx
                y += dy
            z += dz

    def initFormFactors(self, n):
        self.fij = np.zeros([n])

    def dumpFij(self):
        n = len(self.fij)
        for i in range(n):
            print(f"[{self.idt} -> {i}] Fij = {self.fij[i]}")
            
print("class Rectangle: OK")
# Out:
# class Rectangle: OK

# %% [markdown]
# ## Maillage
#
# - un index *maxUnshotIndex* qui pointe sur la surface dont B x A est le plus grand cette itération
# - un moyen de réinitialiser les calculs précédents *resetRadiosity*
# - une méthode pour rechercher la surface ayant la plus forte radiosité à émettre *initRadiosity*
# - une méthode pour résoudre de manière itérative le système en suivant l'algorithme présenté en début de page *solveRadiosity*. La convergence est estimée sur la quantité totale de "radiosité" émise lors de cette itération avec un garde fou sur le nombre maximal d'itérations
#
# ### Optimisation(s)
#
# - le calcul des facteurs dans sa version initiale occupe 90% du temps nécessaire à l'intégralité des tâches d'éclairage
# - En notant que $F_{ji} = \frac{Ai}{Aj}F_{ij}$, on élimine la moitié des calculs (cf. _getFormFactors_uni_sq2()_)
# - je ne sais pas pourquoi mais le calcul de la norme d'un vecteur (np.linalg.norm()) s'avère relativement couteux, on obtient un gain en le remplaçant explicitement par ce qu'il représente (somme ri.norm[k] nrij[k])
# - Sur une machine de teste, on passe pour une grille 10x10, on passe de 13.8s à 4.2s

# %%
class Mesh():
    def __init__(self):
        self.poly = []
        # Radiosity
        self.maxUnshotIndex = -1

    def add(self, item):
        self.poly.append(item)

    def get(self, index):
        return self.poly[index]

    def resetRadiosity(self, rho=DEFAULT_RHO):
        for p in self.poly:
            p.resetRadiosity()
    
    def resetLights(self):
        for p in self.poly:
            p.E = 0.
            p.B = p.E
            p.dB = p.E
    
    def initRadiosity(self):
        # find poly with max E
        maxUnshot = 0.
        for p in self.poly:
            unshot = p.dB * p.area
            if  unshot > maxUnshot:
                maxUnshot = unshot
                self.maxUnshotIndex = p.idt
        print(f"[initRadiosity] maxUnshotIndex = {self.maxUnshotIndex}")

    def solveRadiosity(self, epsilon=1., n=100):
        step = 0.
        sumdRad = epsilon
        while sumdRad >= epsilon and step < n :
            src = self.get(self.maxUnshotIndex)
            maxUnshot = 0.
            sumdRad = 0.
            for rec in self.poly:
                if rec.idt != src.idt:
                    dRad = src.dB * rec.rho * rec.fij[src.idt]
                    rec.dB += dRad
                    rec.B += dRad
                    tmp_unshot = rec.dB * rec.area
                    sumdRad += dRad
                    if tmp_unshot > maxUnshot:
                        self.maxUnshotIndex = rec.idt
                        maxUnshot = tmp_unshot
            print(f"[{step}] maxUnshotIndex={self.maxUnshotIndex} dB={src.dB} sum dRad = {sumdRad}")
            src.dB = 0
            step += 1

    def showAllBi(self):
        for p in self.poly:
            print(f"B{p.idt} = {p.B}")


    def initFormFactors(self):
        size = len(self.poly)
        for p in self.poly:
            p.initFormFactors(len(self.poly))

    def getFormFactors_uni_sq(self):
        for poly_i in self.poly:
            for poly_j in self.poly:
                if poly_i.idt != poly_j.idt:
                    poly_i.fij[poly_j.idt] = self.getFormFactor_uni_sq(poly_i, poly_j)

    def getFormFactors_uni_sq2(self):
        count = len(self.poly)
        for i in range(count-1):
            poly_i = self.poly[i]
            for j in range(i+1, count):
                poly_j = self.poly[j]
                fij = self.getFormFactor_uni_sq(poly_i, poly_j)
                poly_i.fij[poly_j.idt] = fij
                poly_j.fij[poly_i.idt] = fij * poly_i.area / poly_j.area
                    
    def getFormFactors_rnd(self, n):
        for poly_i in self.poly:
            for poly_j in self.poly:
                if poly_i.idt != poly_j.idt:
                    fij = self.getFormFactor_rnd(poly_i, poly_j, n)
                    #print(f"F({poly_i.idt}, {poly_j.idt}) = {fij}")
                    # TODO: if poly_i != 0, poly_i.fij = (poly_i.fij + fij)/2 ; if poly_j.fij != 0, poly_j.fij = poly_i.fij (??)
                    # TODO: to garanty reciprocity !!! ONLY if i an d j are of the same form !
                    #tmp_fij = poly_i.fij[poly_j.idt]
                    #if tmp_fij != 0.:
                    #    fij = (tmp_fij + fij)/2.
                    poly_i.fij[poly_j.idt] = fij
                    #poly_j.fij[poly_i.idt] = fij
                    #if (poly_i.idt == 24 and poly_j.idt == 0) or (poly_j.idt == 24 and poly_i.idt == 0):
                    #   print(f"[{poly_i.idt} -> {poly_j.idt}] Fij = {poly_i.fij[poly_j.idt]}")
                    #   print(f"[{poly_j.idt} -> {poly_i.idt}] Fij = {poly_j.fij[poly_i.idt]}")

    def getFormFactor_uni_sq(self, ri, rj):
        fij = 0.
        aj = rj.area
        patchs_i = ri.getPatchs()
        patchs_j = rj.getPatchs()
        li = len(patchs_i)
        lj = len(patchs_j)
        samples = li * lj

        for xi in patchs_i:
            for xj in patchs_j:
                # get ray from r1 to r2
                rij = xj - xi
                r = np.linalg.norm(rij)
                nrij = rij / r
                r2 = r*r
                costhetai = np.dot(ri.norm, nrij)
                costhetaj = -1.*np.dot(rj.norm, nrij)
                deltaf = ((costhetai * costhetaj) / (np.pi * r2 + aj/lj))
                #if ri.idt == 1 and (rj.idt == 24 or rj.idt == 27):
                #    if (xi[0]==1.25 and xi[1] == 0.25 and xj[1] == 0.25 and xj[2] == 0.25 and xj[0] == 0.) or (xi[0]==1.75 and xi[1] == 0.25 and xj[1] == 0.25 and xj[2] == 0.25 and xj[0] == 2.):
                #        print(f"{xi} -> {xj} : deltaf: {deltaf} costhetai: {costhetai}, costhetaj: {costhetaj} r2: {r2}")
                if (deltaf > 0.):
                    fij += deltaf
        fij = fij * aj/samples
        return fij


    def getFormFactor_rnd(self, ri, rj, n=1):
        fij = 0.
        aj = rj.area
        for i in range(n):
            # get a point on r1 and r2
            xi = ri.getRandomPoint()
            xj = rj.getRandomPoint()
            #print(f"xi: {xi} xj: {xj}")
            # get ray from r1 to r2
            rij = xj - xi
            r = np.linalg.norm(rij)
            nrij = rij / r
            #print(f"normalized ray vector: {nrij} ({nrij[0]*nrij[0] + nrij[1]*nrij[1] + nrij[2]*nrij[2]})")
            r2 = r*r
            costhetai = np.dot(ri.norm, nrij)
            costhetaj = -1.*np.dot(rj.norm, nrij)
            #print(f"costhetai: {costhetai}, costhetaj: {costhetaj} r2: {r2}")
            deltaf = ((costhetai * costhetaj) / (np.pi * r2 + aj/n))
            #print(f"deltaf: {deltaf}")
            if (deltaf > 0.):
                fij += deltaf
        fij = fij * aj/n
        return fij

    def showFij(self, i):
        self.poly[i].dumpFij()

print("class Mesh: OK")
# Out:
# class Mesh: OK

# %% [markdown]
# ## Les calculs analitiques
#
# - pas de changement

# %%
def getThFij(a, b, c):
    X = a/c
    Y = b/c
    th_fij = 2/(np.pi*X*Y) * ( np.log(np.power((1+X*X)*(1+Y*Y) / (1+X*X+Y*Y), 1/2  ))
        + X*np.sqrt(1+Y*Y)*np.arctan(X/np.sqrt(1+Y*Y))
        + Y*np.sqrt(1+X*X)*np.arctan(Y/np.sqrt(1+X*X))
        - X*np.arctan(X) - Y*np.arctan(Y))
    print(f"theoritical para. ({a},{b},{c}) Fij = {th_fij}")

def getThPerpFij(a, b, c):
    H = a/c
    W = b/c
    th_fij = (1./(np.pi*W)) * (W*np.arctan(1./W) + H*np.arctan(1./H) - np.sqrt(H*H+W*W)*np.arctan(1./np.sqrt(H*H+W*W))
                                + (1./4.) * np.log( ((1+W*W)*(1+H*H) / (1+W*W+H*H))
                                                * np.power((W*W*(1+W*W+H*H) / ((1+W*W)*(W*W+H*H))),W*W)
                                                * np.power((H*H*(1+W*W+H*H) / ((1+H*H)*(H*H+W*W))),H*H)
                                                ))
    print(f"theoritical perp. ({a},{b},{c}) Fij = {th_fij}")

def g_para_z(x, y, eta, xi, z):
    res = (1./(2.*np.pi)) * (
            (y - eta)*np.sqrt( (x-xi)*(x-xi) + z*z ) * np.arctan( (y-eta)/np.sqrt((x-xi)*(x-xi) + z*z ) )
            + (x-xi)*np.sqrt(  (y-eta)*(y-eta) + z*z ) * np.arctan( (x-xi)/np.sqrt((y-eta)*(y-eta) + z*z ) )
            - (z*z/2.)*np.log( (x-xi)*(x-xi) + (y-eta)*(y-eta) + z*z )
            )
    return res

def getThFij_para_z(r1, r2):
    # http://www.thermalradiation.net/sectionc/C-13.html
    z = r2.cmax[2] - r1.cmax[2]
    x = np.array([r1.cmin[0], r1.cmax[0]])
    y = np.array([r1.cmin[1], r1.cmax[1]])
    xi = np.array([r2.cmin[0], r2.cmax[0]])
    eta = np.array([r2.cmin[1], r2.cmax[1]])

    f12 = 0.
    for l in range(1,3):
        for k in range(1,3):
            for j in range(1,3):
                for i in range(1,3):
                    f12 += np.power(-1, i+j+k+l)*g_para_z(x[i-1], y[j-1], eta[k-1], xi[l-1], z)
    f12 *= 1./ ( (x[2-1] - x[1-1])*(y[2-1] - y[1-1]) )
    print(f"Th Fij ({r1.idt} -> {r2.idt}) = {f12}")

def g_perp_x(x, y, eta, xi):
    K = (y -eta) / np.sqrt(x*x + xi*xi)
    res = (1./(2.*np.pi)) * (
            (y - eta)*np.sqrt( x*x + xi*xi ) * np.arctan(K) - (1./4.)*(x*x +xi*xi)*(1-K*K)
            * np.log((x*x + xi*xi)*(1+K*K))
            )
    return res

def getThFij_perp_x(r1, r2):
    # http://www.thermalradiation.net/sectionc/C-15.html
    if r1.cmin[0] == r2.cmin[2]:
        print("common edge case")
        return 0.
    x = np.array([r1.cmin[0], r1.cmax[0]])
    y = np.array([r1.cmin[1], r1.cmax[1]])
    xi = np.array([r2.cmin[2], r2.cmax[2]])
    eta = np.array([r2.cmin[1], r2.cmax[1]])

    f12 = 0.
    for l in range(1,3):
        for k in range(1,3):
            for j in range(1,3):
                for i in range(1,3):
                    f12 += np.power(-1, i+j+k+l)*g_perp_x(x[i-1], y[j-1], eta[k-1], xi[l-1])
    f12 *= 1./ ( (x[2-1] - x[1-1])*(y[2-1] - y[1-1]) )
    print(f"Th Fij perp ({r1.idt} -> {r2.idt}) = {f12}")

print("analytic functions: OK")
# Out:
# analytic functions: OK

# %% [markdown]
# ## Initialisation du maillage

# %%
c = 2.

mesh = Mesh()

nz_up = np.array([0., 0., 1.])
nz_down = np.array([0., 0., -1.])

ny_up = np.array([0., 1., 0.])
ny_down = np.array([0., -1., 0.])

nx_up = np.array([1., 0., 0.])
nx_down = np.array([-1., 0., 0.])
print("normal vectors: OK")
# Out:
# normal vectors: OK

# %%
WIDTH = 10
HEIGHT = 10
Rect.count = -1
# Construct Mesh
## 1. Floor
print("## FLOOR ##")
for y in range(HEIGHT):
    for x in range(WIDTH):
        mesh.add(Rect(np.array([x, y, 0.]), np.array([x+1., y+1., 0.]), nz_up))

## 1. Ceiling
print("## CEILING ##")
for y in range(HEIGHT):
    for x in range(WIDTH):
        mesh.add(Rect(np.array([x, y, c]), np.array([x+1., y+1., c]), nz_down))

# North Wall
print("## NORTH WALL ##")
y = 0
for x in range(WIDTH):
    mesh.add(Rect(np.array([x, y, 0.]), np.array([x+1, y, c]), ny_up))

# South Wall
print("## SOUTH WALL ##")
y = HEIGHT
for x in range(WIDTH):
    mesh.add(Rect(np.array([x, y, 0.]), np.array([x+1, y, c]), ny_down))

# West Wall
print("## WEST WALL ##")
x = 0
for y in range(HEIGHT):
    mesh.add(Rect(np.array([x, y, 0.]), np.array([x, y+1, c]), nx_up))

# East Wall
print("## EAST WALL ##")
x = WIDTH
for y in range(HEIGHT):
    mesh.add(Rect(np.array([x, y, 0.]), np.array([x, y+1, c]), nx_down))
print("mesh: OK")
# Out:
# ## FLOOR ##
# 0 [0. 0. 0.] [1. 1. 0.] area:1.0
# 1 [1. 0. 0.] [2. 1. 0.] area:1.0
# 2 [2. 0. 0.] [3. 1. 0.] area:1.0
# 3 [3. 0. 0.] [4. 1. 0.] area:1.0
# 4 [4. 0. 0.] [5. 1. 0.] area:1.0
# 5 [5. 0. 0.] [6. 1. 0.] area:1.0
# 6 [6. 0. 0.] [7. 1. 0.] area:1.0
# 7 [7. 0. 0.] [8. 1. 0.] area:1.0
# 8 [8. 0. 0.] [9. 1. 0.] area:1.0
# 9 [9. 0. 0.] [10.  1.  0.] area:1.0
# 10 [0. 1. 0.] [1. 2. 0.] area:1.0
# 11 [1. 1. 0.] [2. 2. 0.] area:1.0
# 12 [2. 1. 0.] [3. 2. 0.] area:1.0
# 13 [3. 1. 0.] [4. 2. 0.] area:1.0
# 14 [4. 1. 0.] [5. 2. 0.] area:1.0
# 15 [5. 1. 0.] [6. 2. 0.] area:1.0
# 16 [6. 1. 0.] [7. 2. 0.] area:1.0
# 17 [7. 1. 0.] [8. 2. 0.] area:1.0
# 18 [8. 1. 0.] [9. 2. 0.] area:1.0
# 19 [9. 1. 0.] [10.  2.  0.] area:1.0
# 20 [0. 2. 0.] [1. 3. 0.] area:1.0
# 21 [1. 2. 0.] [2. 3. 0.] area:1.0
# 22 [2. 2. 0.] [3. 3. 0.] area:1.0
# 23 [3. 2. 0.] [4. 3. 0.] area:1.0
# 24 [4. 2. 0.] [5. 3. 0.] area:1.0
# 25 [5. 2. 0.] [6. 3. 0.] area:1.0
# 26 [6. 2. 0.] [7. 3. 0.] area:1.0
# 27 [7. 2. 0.] [8. 3. 0.] area:1.0
# 28 [8. 2. 0.] [9. 3. 0.] area:1.0
# 29 [9. 2. 0.] [10.  3.  0.] area:1.0
# 30 [0. 3. 0.] [1. 4. 0.] area:1.0
# 31 [1. 3. 0.] [2. 4. 0.] area:1.0
# 32 [2. 3. 0.] [3. 4. 0.] area:1.0
# 33 [3. 3. 0.] [4. 4. 0.] area:1.0
# 34 [4. 3. 0.] [5. 4. 0.] area:1.0
# 35 [5. 3. 0.] [6. 4. 0.] area:1.0
# 36 [6. 3. 0.] [7. 4. 0.] area:1.0
# 37 [7. 3. 0.] [8. 4. 0.] area:1.0
# 38 [8. 3. 0.] [9. 4. 0.] area:1.0
# 39 [9. 3. 0.] [10.  4.  0.] area:1.0
# [1 -> 208] Fij = 0.00012340120617841089
# [1 -> 209] Fij = 7.354318018111842e-05
# [1 -> 210] Fij = 0.0006970084778292351
# [1 -> 211] Fij = 0.0007121570218550628
# [1 -> 212] Fij = 0.0006970084778292353
# [1 -> 213] Fij = 0.0006543467759514181
# [1 -> 214] Fij = 0.0005914517112783679
# [1 -> 215] Fij = 0.0005175540179414683
# [1 -> 216] Fij = 0.00044123555715743455
# [1 -> 217] Fij = 0.0003688395097527389
# [1 -> 218] Fij = 0.00030408807660128564
# [1 -> 219] Fij = 0.0002485027143364284
# [1 -> 220] Fij = 0.06568626051017326
# [1 -> 221] Fij = 0.04150686708646163
# [1 -> 222] Fij = 0.01565637571494623
# [1 -> 223] Fij = 0.005813424394302772
# [1 -> 224] Fij = 0.0024324104405188
# [1 -> 225] Fij = 0.0011505556313481347
# [1 -> 226] Fij = 0.0006026852581149093
# [1 -> 227] Fij = 0.00034250605330311384
# [1 -> 228] Fij = 0.00020773740975641914
# [1 -> 229] Fij = 0.00013280064204007923
# [1 -> 230] Fij = 0.0009841521617144655
# [1 -> 231] Fij = 0.0009582598255247847
# [1 -> 232] Fij = 0.0008864128079416581
# [1 -> 233] Fij = 0.0007833855923271043
# [1 -> 234] Fij = 0.0006667766170509762
# [1 -> 235] Fij = 0.0005514522874268583
# [1 -> 236] Fij = 0.0004469489158428921
# [1 -> 237] Fij = 0.00035763562824515314
# [1 -> 238] Fij = 0.0002842143501706345
# [1 -> 239] Fij = 0.00022534485501028503

# %% [markdown]
# ## Source Lumineuse

# %%
mesh.resetLights()

light = mesh.get(113) 
#light = mesh.get(index) 
#light.initLightSource(31.830, 0.)
# Examples in cd/m^2
# Office (Accounting) 538
# Office              323
# Operating Room    19375
# Twilight             11
# Deep Twilight         1.07
# Moonlight             0.04
# Dusk                107
# Overcast day       1076
# Full dayligh      10764
# Direct sunlight  107639
light.initLightSource(538, 0.)
#light = mesh.get(112)
#light.initLightSource(500, 0.)
print("light source(s) : OK")
# Out:
# light source(s) : OK

# %% [markdown]
# ## Radiosité
#
# Où on teste enfin le système...

# %%
mesh.resetRadiosity()
mesh.initRadiosity()
mesh.solveRadiosity(1., 500)
mesh.showAllBi()
# Out:
# [initRadiosity] maxUnshotIndex = 113
# [0.0] maxUnshotIndex=13 dB=538 sum dRad = 254.35676992856563
# [1.0] maxUnshotIndex=203 dB=20.579768857521387 sum dRad = 9.729746342891504
# [2.0] maxUnshotIndex=3 dB=10.090029458544064 sum dRad = 9.94705835661102
# [3.0] maxUnshotIndex=12 dB=15.45431766332692 sum dRad = 6.527790899183865
# [4.0] maxUnshotIndex=14 dB=14.441247796253919 sum dRad = 6.713792925459972
# [5.0] maxUnshotIndex=23 dB=14.441247796253919 sum dRad = 6.869738365050729
# [6.0] maxUnshotIndex=204 dB=14.348486551753599 sum dRad = 7.105583277718432
# [7.0] maxUnshotIndex=202 dB=7.008320904492894 sum dRad = 6.944530219925686
# [8.0] maxUnshotIndex=4 dB=7.008320904492893 sum dRad = 6.820365056873014
# [9.0] maxUnshotIndex=2 dB=11.491481861202967 sum dRad = 4.880771541184066
# [10.0] maxUnshotIndex=24 dB=11.491481861202965 sum dRad = 4.782659631120592
# [11.0] maxUnshotIndex=22 dB=10.535472604118306 sum dRad = 5.2525308099789
# [12.0] maxUnshotIndex=15 dB=10.535472604118304 sum dRad = 5.1225920737073585
# [13.0] maxUnshotIndex=11 dB=6.257452356673647 sum dRad = 2.97668602662361
# [14.0] maxUnshotIndex=33 dB=6.257452356673645 sum dRad = 2.7910564690735677
# [15.0] maxUnshotIndex=205 dB=6.126201845518822 sum dRad = 3.0925341430535647
# [16.0] maxUnshotIndex=201 dB=3.0617719095262372 sum dRad = 3.033903247580105
# [17.0] maxUnshotIndex=1 dB=3.0617719095262363 sum dRad = 2.892316882201633
# [18.0] maxUnshotIndex=5 dB=5.427934621004002 sum dRad = 2.180416665766576
# [19.0] maxUnshotIndex=221 dB=5.427934621004002 sum dRad = 2.30540405019886
# [20.0] maxUnshotIndex=21 dB=2.6014630059960737 sum dRad = 2.4574839645157365
# [21.0] maxUnshotIndex=25 dB=5.0389518344282465 sum dRad = 2.342628535637591
# [22.0] maxUnshotIndex=32 dB=4.984130320608332 sum dRad = 2.4848717332065253
# [23.0] maxUnshotIndex=34 dB=4.937517146011017 sum dRad = 2.4451316966147982
# [24.0] maxUnshotIndex=103 dB=4.927567902350134 sum dRad = 2.5051552162123447
# [25.0] maxUnshotIndex=222 dB=4.696644087685927 sum dRad = 1.9838281572958067
# [26.0] maxUnshotIndex=203 dB=2.348371576018119 sum dRad = 2.2853907028372205
# [27.0] maxUnshotIndex=220 dB=2.3279817828960976 sum dRad = 2.294995345924015
# [28.0] maxUnshotIndex=113 dB=2.269631096034008 sum dRad = 1.9632731433552315
# [29.0] maxUnshotIndex=102 dB=4.522368500392502 sum dRad = 2.138094877670127
# [30.0] maxUnshotIndex=104 dB=4.043050088129154 sum dRad = 1.6826839807646583
# [31.0] maxUnshotIndex=112 dB=3.989536755779804 sum dRad = 1.6944740195656094
# [32.0] maxUnshotIndex=114 dB=3.9310349954711614 sum dRad = 1.8275536376556063
# [33.0] maxUnshotIndex=123 dB=3.8665944341869456 sum dRad = 1.839348822303015
# [34.0] maxUnshotIndex=200 dB=3.6010516477752477 sum dRad = 1.783294166833575
# [35.0] maxUnshotIndex=223 dB=1.7031260431347908 sum dRad = 1.4732357280785575
# [36.0] maxUnshotIndex=202 dB=1.7071733493313908 sum dRad = 1.6829834838857598
# [37.0] maxUnshotIndex=122 dB=1.6803278672475725 sum dRad = 1.6352632286741093
# [38.0] maxUnshotIndex=204 dB=3.2175104879153515 sum dRad = 1.5644285113534129
# [39.0] maxUnshotIndex=10 dB=1.6176161608120487 sum dRad = 1.6028923997755036
# [40.0] maxUnshotIndex=31 dB=3.2050112994993314 sum dRad = 1.287462089973722
# [41.0] maxUnshotIndex=124 dB=3.193652503584345 sum dRad = 1.509901738078051
# [42.0] maxUnshotIndex=35 dB=3.1676590563061686 sum dRad = 1.5792577527327059
# [43.0] maxUnshotIndex=111 dB=3.064856879880232 sum dRad = 1.5581606081804302
# [44.0] maxUnshotIndex=0 dB=2.8952506182371316 sum dRad = 1.2913894516514728
# [45.0] maxUnshotIndex=101 dB=2.950015294126205 sum dRad = 1.0893209621294082
# [46.0] maxUnshotIndex=20 dB=2.818635417954123 sum dRad = 1.132253807229962
# [47.0] maxUnshotIndex=206 dB=2.816076850581629 sum dRad = 1.1720278754371265
# [48.0] maxUnshotIndex=16 dB=1.3651574349828033 sum dRad = 1.3458137785947346
# [49.0] maxUnshotIndex=115 dB=2.7430808514643563 sum dRad = 1.2968795260806203
# [50.0] maxUnshotIndex=43 dB=2.6811900225576926 sum dRad = 1.2754489239311966
# [51.0] maxUnshotIndex=105 dB=2.62723513157985 sum dRad = 1.3356755146802894
# [52.0] maxUnshotIndex=6 dB=2.576738911511286 sum dRad = 1.0944170734695262
# [53.0] maxUnshotIndex=121 dB=2.612078264547816 sum dRad = 1.103322779738989
# [54.0] maxUnshotIndex=133 dB=2.549404004092491 sum dRad = 1.185227953172818
# [55.0] maxUnshotIndex=26 dB=2.5039965487081077 sum dRad = 1.2640286781658134
# [56.0] maxUnshotIndex=42 dB=2.399128403062534 sum dRad = 1.188083955782572
# [57.0] maxUnshotIndex=224 dB=2.3767654349658813 sum dRad = 1.1849524121368042
# [58.0] maxUnshotIndex=132 dB=1.1981751215241263 sum dRad = 1.187269169545754
# [59.0] maxUnshotIndex=44 dB=2.355603030596842 sum dRad = 1.1665295460102822
# [60.0] maxUnshotIndex=125 dB=2.356536667108299 sum dRad = 1.2067787417917901
# [61.0] maxUnshotIndex=134 dB=2.36152061665252 sum dRad = 1.1773520053119435
# [62.0] maxUnshotIndex=201 dB=2.3069471558820065 sum dRad = 1.1728424276665401
# [63.0] maxUnshotIndex=110 dB=1.153646467898842 sum dRad = 1.0897974290032646
# [64.0] maxUnshotIndex=13 dB=2.11889263138602 sum dRad = 0.8511651537891041
# B0 = 3.1559642980395517
# B1 = 6.499551147153101
# B2 = 12.853419049423605
# B3 = 17.273999176274344
# B4 = 12.727277277129247
# B5 = 6.135337643764788
# B6 = 2.648169933969062
# B7 = 1.1107511276631068
# B8 = 0.5200918517122951
# B9 = 0.27251800635169154
# B10 = 3.526213280935896
# B11 = 7.505487926466226
# B12 = 16.124120351420444
# B13 = 22.652051670421994
# B14 = 15.990530965041224
# B15 = 7.179590217186753
# B16 = 2.933841332070601
# B17 = 1.249405490424235
# B18 = 0.5805438706986166
# B19 = 0.29872678021190024
# B20 = 2.998782587004565
# B21 = 5.936719271743045
# B22 = 11.66968606763609
# B23 = 15.66592790949966
# B24 = 11.558970256384335
# B25 = 5.66633147980387
# B26 = 2.488843163598634
# B27 = 1.1238767692638651
# B28 = 0.5473810123948927
# B29 = 0.29007749531121246
# B30 = 2.0502281250750922
# B31 = 3.4807909629117657
# B32 = 5.67653982381195
# B33 = 6.933781574021686
# B239 = 0.14402015026157397

# %%
B_floor = np.zeros([HEIGHT, WIDTH])
B_ceiling = np.zeros([HEIGHT, WIDTH])
B_NWall = np.zeros([WIDTH])
B_SWall = np.zeros([WIDTH])
B_EWall = np.zeros([HEIGHT])
B_WWall = np.zeros([HEIGHT])

def polyToArrays():
    floorSize = (HEIGHT*WIDTH)
    idxCeiling = floorSize
    idxNWall = 2*floorSize
    idxSWall = idxNWall + WIDTH
    idxEWall = idxSWall + WIDTH
    idxWWall = idxEWall + HEIGHT
    endWWall = idxWWall + HEIGHT
    
    for p in mesh.poly:
        if p.idt >= 0 and p.idt < idxCeiling:
            x = p.idt % WIDTH
            y = int(p.idt / WIDTH)
            B_floor[y, x] = p.B
        elif p.idt >= idxCeiling and p.idt < idxNWall:
            x = (p.idt - idxCeiling) % WIDTH
            y = int((p.idt - idxCeiling) / WIDTH)            
            B_ceiling[y, x] = p.B
        elif p.idt >= idxNWall and p.idt < idxSWall:
            x = (p.idt - idxNWall)
            B_NWall[x] = p.B
        elif p.idt >= idxSWall and p.idt < idxEWall:
            x = (p.idt - idxSWall)
            B_SWall[x] = p.B
        elif p.idt >= idxEWall and p.idt < idxWWall:
            y = (p.idt - idxEWall)
            B_WWall[y] = p.B
        elif p.idt >= idxWWall and p.idt < endWWall:
            y = (p.idt - idxWWall)
            B_EWall[y] = p.B

def fdisplay(data, msg=""):
    df = pd.DataFrame(data).sort_index(ascending=False, axis=0)
    if msg!="":
        display(HTML("<b>"+msg+"</b>"))
    display(HTML(df.style.render()+"</br>"))

def fdisplayTrans(data, msg=""):
    df = pd.DataFrame(data).sort_index(ascending=True, axis=0).transpose()
    if msg!="":
        display(HTML("<b>"+msg+"</b>"))
    display(HTML(df.style.render()+"</br>"))
    
polyToArrays()
#pd.DataFrame(B_NWall).transpose()
fdisplay(B_floor, "Floor")
fdisplay(B_ceiling, "Ceiling")
fdisplayTrans(B_SWall, "South Wall (!Watch out, y axis reverse)")
fdisplayTrans(B_NWall, "North Wall(!Watch out, y axis reverse)")
fdisplay(B_WWall, "West Wall")
fdisplay(B_EWall, "East Wall")
# Out:
# <b>Floor</b>
# <style  type="text/css" >
# </style>
# <table id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >9</th>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >0.0867347</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col1" class="data row0 col1" >0.0998997</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col2" class="data row0 col2" >0.108981</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col3" class="data row0 col3" >0.112189</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col4" class="data row0 col4" >0.108991</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col5" class="data row0 col5" >0.100304</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col6" class="data row0 col6" >0.0880697</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col7" class="data row0 col7" >0.0744568</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col8" class="data row0 col8" >0.0612038</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row0_col9" class="data row0 col9" >0.0493574</td>
#     </tr>    <tr>
#         <th id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83level0_row1" class="row_heading level0 row1" >8</th>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col0" class="data row1 col0" >0.132136</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col1" class="data row1 col1" >0.157596</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col2" class="data row1 col2" >0.175492</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col3" class="data row1 col3" >0.181623</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col4" class="data row1 col4" >0.174677</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col5" class="data row1 col5" >0.156962</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col6" class="data row1 col6" >0.133203</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col7" class="data row1 col7" >0.108229</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col8" class="data row1 col8" >0.0853657</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row1_col9" class="data row1 col9" >0.0661449</td>
#     </tr>    <tr>
#         <th id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83level0_row2" class="row_heading level0 row2" >7</th>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col0" class="data row2 col0" >0.210248</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col1" class="data row2 col1" >0.263124</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col2" class="data row2 col2" >0.301321</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col3" class="data row2 col3" >0.314291</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col4" class="data row2 col4" >0.29805</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col5" class="data row2 col5" >0.258919</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col6" class="data row2 col6" >0.209596</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col7" class="data row2 col7" >0.161512</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col8" class="data row2 col8" >0.120851</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row2_col9" class="data row2 col9" >0.0891784</td>
#     </tr>    <tr>
#         <th id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83level0_row3" class="row_heading level0 row3" >6</th>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row3_col0" class="data row3 col0" >0.352003</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row3_col1" class="data row3 col1" >0.46981</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row3_col2" class="data row3 col2" >0.559034</td>
#         <td id="T_65f2d114_f262_11e8_aaa3_e0cb4e922f83row3_
td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row4_col9" class="data row4 col9" >0.0848171</td>
#     </tr>    <tr>
#         <th id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83level0_row5" class="row_heading level0 row5" >4</th>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col0" class="data row5 col0" >0.820381</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col1" class="data row5 col1" >1.08317</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col2" class="data row5 col2" >1.38658</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col3" class="data row5 col3" >1.50841</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col4" class="data row5 col4" >1.3393</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col5" class="data row5 col5" >0.96994</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col6" class="data row5 col6" >0.599278</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col7" class="data row5 col7" >0.341308</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col8" class="data row5 col8" >0.192068</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row5_col9" class="data row5 col9" >0.111205</td>
#     </tr>    <tr>
#         <th id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83level0_row6" class="row_heading level0 row6" >3</th>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row6_col0" class="data row6 col0" >1.33181</td>
#         <td id="T_6601a25c_f262_11e8_aaa3_e0cb4e922f83row6_
# <b>South Wall (!Watch out, y axis reverse)</b>
# <style  type="text/css" >
# </style>
# <table id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >0.301219</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col1" class="data row0 col1" >0.342959</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col2" class="data row0 col2" >0.371333</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col3" class="data row0 col3" >0.381672</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col4" class="data row0 col4" >0.372905</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col5" class="data row0 col5" >0.34768</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col6" class="data row0 col6" >0.311211</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col7" class="data row0 col7" >0.269412</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col8" class="data row0 col8" >0.227299</td>
#         <td id="T_66156d78_f262_11e8_aaa3_e0cb4e922f83row0_col9" class="data row0 col9" >0.188241</td>
#     </tr></tbody>
# </table> </br>
# <b>North Wall(!Watch out, y axis reverse)</b>
# <style  type="text/css" >
# </style>
# <table id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >2.13815</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col1" class="data row0 col1" >4.2396</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col2" class="data row0 col2" >8.91067</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col3" class="data row0 col3" >12.9161</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col4" class="data row0 col4" >8.81879</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col5" class="data row0 col5" >4.00911</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col6" class="data row0 col6" >1.69356</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col7" class="data row0 col7" >0.683629</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col8" class="data row0 col8" >0.309578</td>
#         <td id="T_661cd9c8_f262_11e8_aaa3_e0cb4e922f83row0_col9" class="data row0 col9" >0.159387</td>
#     </tr></tbody>
# </table> </br>
# <b>West Wall</b>
# <style  type="text/css" >
# </style>
# <table id="T_66258442_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >9</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >0.125269</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row1" class="row_heading level0 row1" >8</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row1_col0" class="data row1 col0" >0.18404</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row2" class="row_heading level0 row2" >7</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row2_col0" class="data row2 col0" >0.281091</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row3" class="row_heading level0 row3" >6</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row3_col0" class="data row3 col0" >0.446867</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row4_col0" class="data row4 col0" >0.73508</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row5" class="row_heading level0 row5" >4</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row5_col0" class="data row5 col0" >1.22659</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row6" class="row_heading level0 row6" >3</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row6_col0" class="data row6 col0" >1.99001</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row7" class="row_heading level0 row7" >2</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row7_col0" class="data row7 col0" >2.96878</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row8" class="row_heading level0 row8" >1</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row8_col0" class="data row8 col0" >3.52036</td>
#     </tr>    <tr>
#         <th id="T_66258442_f262_11e8_aaa3_e0cb4e922f83level0_row9" class="row_heading level0 row9" >0</th>
#         <td id="T_66258442_f262_11e8_aaa3_e0cb4e922f83row9_col0" class="data row9 col0" >3.02188</td>
#     </tr></tbody>
# </table> </br>
# <b>East Wall</b>
# <style  type="text/css" >
# </style>
# <table id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >9</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >0.14402</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row1" class="row_heading level0 row1" >8</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row1_col0" class="data row1 col0" >0.185092</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row2" class="row_heading level0 row2" >7</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row2_col0" class="data row2 col0" >0.238642</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row3" class="row_heading level0 row3" >6</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row3_col0" class="data row3 col0" >0.306785</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row4_col0" class="data row4 col0" >0.389396</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row5" class="row_heading level0 row5" >4</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row5_col0" class="data row5 col0" >0.480918</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row6" class="row_heading level0 row6" >3</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row6_col0" class="data row6 col0" >0.566388</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row7" class="row_heading level0 row7" >2</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row7_col0" class="data row7 col0" >0.620175</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row8" class="row_heading level0 row8" >1</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row8_col0" class="data row8 col0" >0.613865</td>
#     </tr>    <tr>
#         <th id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83level0_row9" class="row_heading level0 row9" >0</th>
#         <td id="T_66337caa_f262_11e8_aaa3_e0cb4e922f83row9_col0" class="data row9 col0" >0.535493</td>
#     </tr></tbody>
# </table> </br>

# %% [markdown]
# ## Représentation
#
# - une représentation rapide avec une dataframe

# %% [markdown]
# Convertion basique des valeurs de radiosité en normalisant les valeurs sur la plage correspondant au sol à partir de la radiosité maximale de la surface). Quick'n dirty

# %%
lighting_color = np.zeros([HEIGHT, WIDTH])

def normalizeMatrix(data, m=0):
    maxB = data.max() if m == 0 else m
    idx = 1 if len(np.shape(data)) == 2 else 0
    d = np.full([np.shape(data)[idx]], maxB)
    data /=  d
    return maxB

data = np.copy(B_floor)
normalizeMatrix(data)
convertRatioToRGB(data)
fakeDisplay("testing...", False)
# Out:
# <b>testing...</b>
# <style  type="text/css" >
# </style>
# <table id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >9</th>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >0</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col1" class="data row0 col1" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col2" class="data row0 col2" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col3" class="data row0 col3" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col4" class="data row0 col4" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col5" class="data row0 col5" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col6" class="data row0 col6" >0</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col7" class="data row0 col7" >0</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col8" class="data row0 col8" >0</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row0_col9" class="data row0 col9" >0</td>
#     </tr>    <tr>
#         <th id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83level0_row1" class="row_heading level0 row1" >8</th>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col0" class="data row1 col0" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col1" class="data row1 col1" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col2" class="data row1 col2" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col3" class="data row1 col3" >2</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col4" class="data row1 col4" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col5" class="data row1 col5" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col6" class="data row1 col6" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col7" class="data row1 col7" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col8" class="data row1 col8" >0</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row1_col9" class="data row1 col9" >0</td>
#     </tr>    <tr>
#         <th id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83level0_row2" class="row_heading level0 row2" >7</th>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col0" class="data row2 col0" >2</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col1" class="data row2 col1" >2</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col2" class="data row2 col2" >3</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col3" class="data row2 col3" >3</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col4" class="data row2 col4" >3</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col5" class="data row2 col5" >2</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col6" class="data row2 col6" >2</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col7" class="data row2 col7" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col8" class="data row2 col8" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row2_col9" class="data row2 col9" >1</td>
#     </tr>    <tr>
#         <th id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83level0_row3" class="row_heading level0 row3" >6</th>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col0" class="data row3 col0" >3</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col1" class="data row3 col1" >5</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col2" class="data row3 col2" >6</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col3" class="data row3 col3" >6</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col4" class="data row3 col4" >6</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col5" class="data row3 col5" >5</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col6" class="data row3 col6" >3</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col7" class="data row3 col7" >2</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col8" class="data row3 col8" >1</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row3_col9" class="data row3 col9" >1</td>
#     </tr>    <tr>
#         <th id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col0" class="data row4 col0" >7</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col1" class="data row4 col1" >10</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col2" class="data row4 col2" >12</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col3" class="data row4 col3" >13</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col4" class="data row4 col4" >12</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col5" class="data row4 col5" >9</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col6" class="data row4 col6" >6</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col7" class="data row4 col7" >4</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col8" class="data row4 col8" >2</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row4_col9" class="data row4 col9" >1</td>
#     </tr>    <tr>
#         <th id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83level0_row5" class="row_heading level0 row5" >4</th>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col0" class="data row5 col0" >13</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col1" class="data row5 col1" >20</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col2" class="data row5 col2" >28</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col3" class="data row5 col3" >31</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col4" class="data row5 col4" >27</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col5" class="data row5 col5" >18</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col6" class="data row5 col6" >11</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col7" class="data row5 col7" >6</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col8" class="data row5 col8" >3</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row5_col9" class="data row5 col9" >2</td>
#     </tr>    <tr>
#         <th id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83level0_row6" class="row_heading level0 row6" >3</th>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row6_col0" class="data row6 col0" >23</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row6_col1" class="data row6 col1" >39</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row6_col2" class="data row6 col2" >63</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row6_col3" class="data row6 col3" >78</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row6_col4" class="data row6 col4" >63</td>
#         <td id="T_66665d64_f262_11e8_aaa3_e0cb4e922f83row6_col5" class="data row6 col5" >37</t

# %%
def destructiveGnlRatioToRGB(source):
    #normalizeMatrix(source)
    dim = len(np.shape(source))
    if dim == 1:
        maxu = np.shape(source)[0]
        for u in range(maxu):
            if source[u] != 0.:
                source[u] = int(abs(source[u]) * 255)
    elif dim == 2:
        maxy = np.shape(source)[0]
        maxx = np.shape(source)[1]
        for y in range(maxy):
            for x in range(maxx):
                if source[y, x] != 0.:
                    source[y, x] = int(abs(source[y, x]) * 255)

def fcoldisplay(data, msg=""):
    df = pd.DataFrame(data).sort_index(ascending=False, axis=0)
    s = df.style.applymap(color_max_red)
    if msg!="":
        display(HTML("<b>"+msg+"</b>"))
    display(HTML(s.render()+"</br>"))

def fcoldisplayTrans(data, msg=""):
    df = pd.DataFrame(data).sort_index(ascending=True, axis=0).transpose()
    s = df.style.applymap(color_max_red)
    if msg!="":
        display(HTML("<b>"+msg+"</b>"))
    display(HTML(s.render()+"</br>"))

B_floor_std = np.copy(B_floor)
m = normalizeMatrix(B_floor_std)
destructiveGnlRatioToRGB(B_floor_std)

#B_ceiling_std = np.copy(B_ceiling)
#normalizeMatrix(B_ceiling_std, m)
#destructiveGnlRatioToRGB(B_ceiling_std)

B_NWall_std = np.copy(B_NWall)
normalizeMatrix(B_NWall_std, m)
destructiveGnlRatioToRGB(B_NWall_std)

B_SWall_std = np.copy(B_SWall)
normalizeMatrix(B_SWall_std, m)
destructiveGnlRatioToRGB(B_SWall_std)

#B_WWall_std = np.copy(B_WWall)
#normalizeMatrix(B_WWall_std, m)
#destructiveGnlRatioToRGB(B_WWall_std)

#B_EWall_std = np.copy(B_EWall)
#normalizeMatrix(B_EWall_std, m)
#destructiveGnlRatioToRGB(B_EWall_std)

fcoldisplayTrans(B_SWall_std)
fcoldisplay(B_floor_std)
fcoldisplayTrans(B_NWall_std)
# Out:
# <style  type="text/css" >
#     #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col0 {
#             background-color:  #030303;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col1 {
#             background-color:  #030303;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col2 {
#             background-color:  #040404;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col3 {
#             background-color:  #040404;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col4 {
#             background-color:  #040404;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col5 {
#             background-color:  #030303;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col6 {
#             background-color:  #030303;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col7 {
#             background-color:  #030303;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col8 {
#             background-color:  #020202;
#         }    #T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col9 {
#             background-color:  #020202;
#         }</style>
# <table id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >3</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col1" class="data row0 col1" >3</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col2" class="data row0 col2" >4</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col3" class="data row0 col3" >4</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col4" class="data row0 col4" >4</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col5" class="data row0 col5" >3</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col6" class="data row0 col6" >3</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col7" class="data row0 col7" >3</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col8" class="data row0 col8" >2</td>
#         <td id="T_66de517a_f262_11e8_aaa3_e0cb4e922f83row0_col9" class="data row0 col9" >2</td>
#     </tr></tbody>
# </table> </br>
# <style  type="text/css" >
#     #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col0 {
#             background-color:  #000000;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col1 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col2 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col3 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col4 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col5 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col6 {
#             background-color:  #000000;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col7 {
#             background-color:  #000000;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col8 {
#             background-color:  #000000;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row0_col9 {
#             background-color:  #000000;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col0 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col1 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col2 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col3 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col4 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col5 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col6 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col7 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col8 {
#             background-color:  #000000;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row1_col9 {
#             background-color:  #000000;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col0 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col1 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col2 {
#             background-color:  #030303;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col3 {
#             background-color:  #030303;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col4 {
#             background-color:  #030303;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col5 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col6 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col7 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col8 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row2_col9 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col0 {
#             background-color:  #030303;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col1 {
#             background-color:  #050505;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col2 {
#             background-color:  #060606;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col3 {
#             background-color:  #060606;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col4 {
#             background-color:  #060606;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col5 {
#             background-color:  #050505;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col6 {
#             background-color:  #030303;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col7 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col8 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row3_col9 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col0 {
#             background-color:  #070707;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col1 {
#             background-color:  #0a0a0a;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col2 {
#             background-color:  #0c0c0c;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col3 {
#             background-color:  #0d0d0d;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col4 {
#             background-color:  #0c0c0c;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col5 {
#             background-color:  #090909;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col6 {
#             background-color:  #060606;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col7 {
#             background-color:  #040404;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col8 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row4_col9 {
#             background-color:  #010101;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col0 {
#             background-color:  #0d0d0d;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col1 {
#             background-color:  #141414;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col2 {
#             background-color:  #1c1c1c;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col3 {
#             background-color:  #1f1f1f;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col4 {
#             background-color:  #1b1b1b;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col5 {
#             background-color:  #121212;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col6 {
#             background-color:  #0b0b0b;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col7 {
#             background-color:  #060606;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col8 {
#             background-color:  #030303;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row5_col9 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col0 {
#             background-color:  #171717;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col1 {
#             background-color:  #272727;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col2 {
#             background-color:  #3f3f3f;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col3 {
#             background-color:  #4e4e4e;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col4 {
#             background-color:  #3f3f3f;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col5 {
#             background-color:  #252525;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col6 {
#             background-color:  #131313;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col7 {
#             background-color:  #090909;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col8 {
#             background-color:  #050505;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row6_col9 {
#             background-color:  #020202;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row7_col0 {
#             background-color:  #212121;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row7_col1 {
#             background-color:  #424242;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row7_col2 {
#             background-color:  #838383;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row7_col3 {
#             background-color:  #b0b0b0;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row7_col4 {
#             background-color:  #828282;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row7_col5 {
#             background-color:  #3f3f3f;
#         }    #T_673729e4_f262_11e8_aaa3_e0cb4e922f83row7_col6 {
#             bac
# <style  type="text/css" >
#     #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col0 {
#             background-color:  #181818;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col1 {
#             background-color:  #2f2f2f;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col2 {
#             background-color:  #646464;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col3 {
#             background-color:  #919191;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col4 {
#             background-color:  #636363;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col5 {
#             background-color:  #2d2d2d;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col6 {
#             background-color:  #131313;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col7 {
#             background-color:  #070707;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col8 {
#             background-color:  #030303;
#         }    #T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col9 {
#             background-color:  #010101;
#         }</style>
# <table id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >24</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col1" class="data row0 col1" >47</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col2" class="data row0 col2" >100</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col3" class="data row0 col3" >145</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col4" class="data row0 col4" >99</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col5" class="data row0 col5" >45</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col6" class="data row0 col6" >19</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col7" class="data row0 col7" >7</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col8" class="data row0 col8" >3</td>
#         <td id="T_6753504c_f262_11e8_aaa3_e0cb4e922f83row0_col9" class="data row0 col9" >1</td>
#     </tr></tbody>
# </table> </br>

# %% [markdown]
# ## Bilan
#
# ### Général
#
# - on a bien le jeu de réfexion autour de la lumière
# - sans surprise, la détermination des facteurs de formes de la scène font très mal (126 surfaces x 4 patchs par surface avec un algorithme en O(n^2)
# - qui ne sont calculés qu'une fois tant que la géométrie de la scène n'est pas changée
# - pré-calculs... qui doivent être fait à la génération du vaisseau
# - ... mais aucune optimisation n'a été mise en place
#     - coté symétrie, on peut lier Fji à Fij en fonction des aires
#     - passer de 16 rayons à 4
#     - ...
#
# ### Affichage
#
# Il y a un problème important avec la technique que nous avons utilisée jusque là pour convertir la radiance en niveaux de gris : **quelque soit la puissance de la source lumineuse, toutes les valeurs sont ramenées dans la plage [0 ; 1] (puis [0; 255] de manière linéaire**.

# %% [markdown]
# ## Et maintenant ?
#
# plusieurs pistes :
#
# - améliorer le calcul des facteurs de forme
# - introduire les occlusions
# - corriger la répartition des niveaux de gris
# - "tonal mode" pour simuler le comportement de l'oeil humain et gérer les écarts de luminosité

# %% [markdown]
# ## Tone mapping operators

# %% [markdown]
# - **TODO:** Attention à la somme pour la moyenne
# - **TODO:** Attention au **gamma**, si gamma = 0.45 (1/2.2), le résultat ressemble plus à ce qui est attendu quand la source est faible

# %%
mesh.resetLights()

light = mesh.get(113) 
#light = mesh.get(index) 
#light.initLightSource(31.830, 0.)
# Examples in cd/m^2
# Office (Accounting) 538
# Office              323
# Operating Room    19375
# Twilight             11
# Deep Twilight         1.07
# Moonlight             0.04
# Dusk                107
# Overcast day       1076
# Full dayligh      10764
# Direct sunlight  107639
intensity = 323
light.initLightSource(intensity, 0.)
print("light source(s) : OK")

mesh.resetRadiosity()
mesh.initRadiosity()
mesh.solveRadiosity(intensity/1000, 500)
print("Radiance : OK")

polyToArrays()
print("Poly to arrays : OK")
# Out:
# light source(s) : OK
# [initRadiosity] maxUnshotIndex = 113
# [0.0] maxUnshotIndex=13 dB=323 sum dRad = 152.70861837718718
# [1.0] maxUnshotIndex=203 dB=12.355511786207076 sum dRad = 5.841464811810335
# [2.0] maxUnshotIndex=3 dB=6.0577686154456 sum dRad = 5.971932805177247
# [3.0] maxUnshotIndex=12 dB=9.278335697499248 sum dRad = 3.919101227576928
# [4.0] maxUnshotIndex=14 dB=8.670117171356905 sum dRad = 4.030771589077272
# [5.0] maxUnshotIndex=23 dB=8.670117171356905 sum dRad = 4.1243968251141006
# [6.0] maxUnshotIndex=204 dB=8.614425940922697 sum dRad = 4.265991447403445
# [7.0] maxUnshotIndex=202 dB=4.207597866452054 sum dRad = 4.1692997417025985
# [8.0] maxUnshotIndex=4 dB=4.207597866452053 sum dRad = 4.094754485817808
# [9.0] maxUnshotIndex=2 dB=6.8991610430642325 sum dRad = 2.9302773379227762
# [10.0] maxUnshotIndex=24 dB=6.899161043064231 sum dRad = 2.8713737190556716
# [11.0] maxUnshotIndex=22 dB=6.325200095037569 sum dRad = 3.153471099671343
# [12.0] maxUnshotIndex=15 dB=6.325200095037567 sum dRad = 3.075459553545493
# [13.0] maxUnshotIndex=11 dB=3.7567976044713522 sum dRad = 1.7871181907052536
# [14.0] maxUnshotIndex=33 dB=3.7567976044713514 sum dRad = 1.675671448904763
# [15.0] maxUnshotIndex=205 dB=3.6779985057668765 sum dRad = 1.856670126777515
# [16.0] maxUnshotIndex=201 dB=1.8382013508865696 sum dRad = 1.8214697936215123
# [17.0] maxUnshotIndex=1 dB=1.838201350886569 sum dRad = 1.7364653400578576
# [18.0] maxUnshotIndex=5 dB=3.2587785921641124 sum dRad = 1.3090605632762151
# [19.0] maxUnshotIndex=221 dB=3.2587785921641124 sum dRad = 1.3840994576472703
# [20.0] maxUnshotIndex=21 dB=1.5618448902169737 sum dRad = 1.4754039415215305
# [21.0] maxUnshotIndex=25 dB=3.025244316952274 sum dRad = 1.4064479870091866
# [22.0] maxUnshotIndex=32 dB=2.9923310289154106 sum dRad = 1.4918467840626501
# [23.0] maxUnshotIndex=34 dB=2.964345795839328 sum dRad = 1.4679879888598135
# [24.0] maxUnshotIndex=103 dB=2.958372551039207 sum dRad = 1.5040244141944028
# [25.0] maxUnshotIndex=222 dB=2.819732416956419 sum dRad = 1.1910343769638387
# [26.0] maxUnshotIndex=203 dB=1.4098959461967517 sum dRad = 1.3720840093242022
# [27.0] maxUnshotIndex=220 dB=1.397654490474794 sum dRad = 1.3778503656755705
# [28.0] maxUnshotIndex=113 dB=1.3626223866523868 sum dRad = 1.1786937273303704
# [29.0] maxUnshotIndex=102 dB=2.7151022781166865 sum dRad = 1.2836517574116177
# [30.0] maxUnshotIndex=104 dB=2.4273330454753093 sum dRad = 1.0102359215371455
# [31.0] maxUnshotIndex=112 dB=2.3952051526335985 sum dRad = 1.0173143277317684
# [32.0] maxUnshotIndex=114 dB=2.360082348582129 sum dRad = 1.0972115705627523
# [33.0] maxUnshotIndex=123 dB=2.32139405621261 sum dRad = 1.104293066178207
# [34.0] maxUnshotIndex=200 dB=2.1619696695751016 sum dRad = 1.070639434734655
# [35.0] maxUnshotIndex=223 dB=1.0225087582389167 sum dRad = 0.8844891081215137
# [36.0] maxUnshotIndex=202 dB=1.0249386465316712 sum dRad = 1.0104157347492575
# [37.0] maxUnshotIndex=122 dB=1.0088213775482633 sum dRad = 0.9817658417504398
# [38.0] maxUnshotIndex=204 dB=1.9317023933023387 sum dRad = 0.9392386787493547
# [39.0] maxUnshotIndex=10 dB=0.9711710407849283 sum dRad = 0.962331310645888
# [40.0] maxUnshotIndex=31 dB=1.9241982337142824 sum dRad = 0.7729558644266025
# [41.0] maxUnshotIndex=124 dB=1.917378733564579 sum dRad = 0.906502344608198
# [42.0] maxUnshotIndex=35 dB=1.9017730022061192 sum dRad = 0.9481417363060656
# [43.0] maxUnshotIndex=111 dB=1.8400534799280948 sum dRad = 0.9354756067700358
# [44.0] maxUnshotIndex=0 dB=1.7382266722873476 sum dRad = 0.7753137414190056
# [45.0] maxUnshotIndex=101 dB=1.7711058364363648 sum dRad = 0.6539975293081767
# [46.0] maxUnshotIndex=20 dB=1.6922290706304497 sum dRad = 0.6797731965339742
# [47.0] maxUnshotIndex=206 dB=1.6906929790666665 sum dRad = 0.7036524233572348
# [48.0] maxUnshotIndex=16 dB=0.8196019544599362 sum dRad = 0.8079885696767637
# [49.0] maxUnshotIndex=115 dB=1.6468682435371502 sum dRad = 0.7786098269963566
# [50.0] maxUnshotIndex=43 dB=1.6097107384500635 sum dRad = 0.765743498940104
# [51.0] maxUnshotIndex=105 dB=1.5773177462830694 sum dRad = 0.8019018424567543
# [52.0] maxUnshotIndex=6 dB=1.547001242412909 sum dRad = 0.6570570905774293
# [53.0] maxUnshotIndex=121 dB=1.5682179915407894 sum dRad = 0.6624038250105824
# [54.0] maxUnshotIndex=133 dB=1.5305901362860133 sum dRad = 0.7115773770907438
# [55.0] maxUnshotIndex=26 dB=1.5033287829604431 sum dRad = 0.7588871060363526
# [56.0] maxUnshotIndex=42 dB=1.4403689111323394 sum dRad = 0.7132920403676044
# [57.0] maxUnshotIndex=224 dB=1.426942816903307 sum dRad = 0.7114119500375229
# [58.0] maxUnshotIndex=132 dB=0.7193504911752654 sum dRad = 0.7128028657310013
# [59.0] maxUnshotIndex=44 dB=1.414237507217062 sum dRad = 0.7003513817124926
# [60.0] maxUnshotIndex=125 dB=1.414798036200707 sum dRad = 0.7245158617077098
# [61.0] maxUnshotIndex=134 dB=1.4177902586965878 sum dRad = 0.7068488805125609
# [62.0] maxUnshotIndex=201 dB=1.3850258947023941 sum dRad = 0.7041414575024022
# [63.0] maxUnshotIndex=110 dB=0.6926167455972607 sum dRad = 0.6542835865577225
# [64.0] maxUnshotIndex=13 dB=1.2721232712596366 sum dRad = 0.5110155105462463
# [65.0] maxUnshotIndex=30 dB=1.2441400530983262 sum dRad = 0.5882071472952501
# [66.0] maxUnshotIndex=100 dB=1.230899041634303 sum dRad = 0.5199227644234148
# [67.0] maxUnshotIndex=221 dB=1.1653069343064264 sum dRad = 0.4303005728079598
# [68.0] maxUnshotIndex=120 dB=0.5763201807581269 sum dRad = 0.5444235029963927
# [69.0] maxUnshotIndex=205 dB=1.166467277639033 sum dRad = 0.48547402564522996
# [70.0] maxUnshotIndex=131 dB=0.57674271342926 sum dRad = 0.5714931232620609
# [71.0] maxUnshotIndex=41 dB=1.1434593450682664 sum dRad = 0.5406071106992523
# [72.0] maxUnshotIndex=3 dB=1.1206517711811652 sum dRad = 0.5330969023564799
# [73.0] maxUnshotIndex=220 dB=1.1095009745233426 sum dRad = 0.46864510759447886
# [74.0] maxUnshotIndex=12 dB=0.5374559656348225 sum dRad = 0.46490941409409053
# [75.0] maxUnshotIndex=36 dB=1.0567151967334731 sum dRad = 0.4912710530384768
# [76.0] maxUnshotIndex=135 dB=1.0200052111160223 sum dRad = 0.5149032012022646
# [77.0] maxUnshotIndex=45 dB=1.035703264277156 sum dRad = 0.5265472716701913
# [78.0] maxUnshotIndex=222 dB=1.0403520865637093 sum dRad = 0.5327626765020402
# [79.0] maxUnshotIndex=116 dB=0.49927270771521665 sum dRad = 0.48588273510252894
# [80.0] maxUnshotIndex=14 dB=0.9925097409478085 sum dRad = 0.4692408398329409
# [81.0] maxUnshotIndex=143 dB=0.9751467622368403 sum dRad = 0.46387979893476766
# [82.0] maxUnshotIndex=225 dB=0.9581257815350824 sum dRad = 0.4871071991225884
# [83.0] maxUnshotIndex=106 dB=0.4727498605050739 sum dRad = 0.4684468273475402
# [84.0] maxUnshotIndex=142 dB=0.9191016510025691 sum dRad = 0.38822182405870453
# [85.0] maxUnshotIndex=130 dB=0.9042320436051866 sum dRad = 0.45081097420820476
# [86.0] maxUnshotIndex=200 dB=0.9026141075599542 sum dRad = 0.3812576061372623
# [87.0] maxUnshotIndex=207 dB=0.45162189158848665 sum dRad = 0.3906613423901021
# [88.0] maxUnshotIndex=126 dB=0.44899031186702065 sum dRad = 0.43694886059928856
# [89.0] maxUnshotIndex=203 dB=0.8937682279130099 sum dRad = 0.44260727788315485
# [90.0] maxUnshotIndex=2 dB=0.4449624140319952 sum dRad = 0.43865750016486366
# [91.0] maxUnshotIndex=11 dB=0.8859395886065244 sum dRad = 0.36872072350784324
# [92.0] maxUnshotIndex=144 dB=0.8841219942073294 sum dRad = 0.39435129038590777
# [93.0] maxUnshotIndex=23 dB=0.871423731169427 sum dRad = 0.4462547298950298
# [94.0] maxUnshotIndex=17 dB=0.8787782911315956 sum dRad = 0.43518403894127106
# [95.0] maxUnshotIndex=40 dB=0.843275548441694 sum dRad = 0.3920421206822479
# [96.0] maxUnshotIndex=232 dB=0.840110935056651 sum dRad = 0.35681991172135885
# [97.0] maxUnshotIndex=53 dB=0.41310229264323545 sum dRad = 0.4020233205719509
# [98.0] maxUnshotIndex=231 dB=0.822201883892907 sum dRad = 0.41800404967155674
# [99.0] maxUnshotIndex=4 dB=0.41021945324259235 sum dRad = 0.3875156886538505
# [100.0] maxUnshotIndex=223 dB=0.8174277000365671 sum dRad = 0.34718567226597613
# [101.0] maxUnshotIndex=141 dB=0.40661769308051177 sum dRad = 0.40085610636919006
# [102.0] maxUnshotIndex=22 dB=0.799884285242445 sum dRad = 0.38050699215594225
# [103.0] maxUnshotIndex=7 dB=0.800520252827937 sum dRad = 0.3892315851474596
# [104.0] maxUnshotIndex=52 dB=0.7907943705137778 sum dRad = 0.32912207129200893
# [105.0] maxUnshotIndex=27 dB=0.782343368211653 sum dRad = 0.3900425543233875
# [106.0] maxUnshotIndex=233 dB=0.7625216033311726 sum dRad = 0.3707557570533671
# [107.0] maxUnshotIndex=1 dB=0.38398949542242966 sum dRad = 0.37854853992107856
# [108.0] maxUnshotIndex=54 dB=0.756024600221205 sum dRad = 0.3036972169253794
# Radiance : OK
# Poly to arrays : OK

# %% [markdown]
# ### Tone Reproduction for Realistic Computer Generated Images, J.E. Tumblin & H.E Rushmeier
#
# #### Version originale 1991

# %%
# https://smartech.gatech.edu/bitstream/handle/1853/3699/91-13.pdf?sequence=1&isAllowed=y
# Tone Reproduction for Realistic Computer Generated Images, J.E. Tumblin, H.E. Rushmeier 1991
gamma = 2.2

avg_llrw = 0.
count = 0
for p in mesh.poly:
    if p.B != 0. and p.rho != -1. :
        avg_llrw += np.log10(p.B * np.pi / 10000)
        count += 1

avg_llrw /= count
llwrw = avg_llrw + 0.84

ldmax = 150.*np.pi / 10000

llwd = -1.569

arw = 0.4*llwrw + 2.92
brw = -0.4*(llwrw*llwrw) + (-2.584*llwrw) + 2.0208

ad = 0.4*llwd + 2.92
bd = -0.4*(llwd*llwd) + (-2.584*llwd) + 2.0208

print(f"ldmax: {ldmax} ; llwrw: {llwrw} (avg_llrw: {avg_llrw}) ; llwd: {llwd} ; arw: {arw} ; brw: {brw} ; ad: {ad} ; bd: {bd}")

# Power law
# np.power( (1/ldmax)* np.power((B_floor[y, x]*np.pi/10000), arw/ad ) * np.power(10., (brw - bd)/ad), 1/gamma)
#  = k*(B_floor[y, x]*np.pi/10000)^q
k = np.power((1/ldmax), (1/gamma)) * np.power(10, (((brw - bd)/ad)*(1/gamma)))
q = (arw/ad) * 1/gamma
#print(f"k: {k} ; q: {q}")
#k*np.power(12.5688*np.pi/10000, q)


B_floor_sf = np.zeros([HEIGHT, WIDTH])
for y in range(HEIGHT):
    for x in range(WIDTH):
        #n = np.power( (1/ldmax)* np.power((B_floor[y, x]*np.pi/10000), arw/ad ) * np.power(10., (brw - bd)/ad), 1/gamma)
        n = k*np.power(B_floor[y, x]*np.pi/10000, q)
        B_floor_sf[y, x] = n 

fdisplay(B_floor_sf, f"Floor sf")


data = np.copy(B_floor_sf)
lighting_color = np.zeros([HEIGHT, WIDTH])
convertRatioToRGB(data)
fakeDisplay("testing...", True)
k = np.power((1/ldmax), (1/gamma)) * np.power(10, (((brw - bd)/ad)*(1/gamma)))
q = (arw/ad) * 1/gamma
print(f"k: {k} ; q: {q}")
k*np.power(12.5688*np.pi/10000, q)
# Out:
# ldmax: 0.047123889803846894 ; llwrw: -3.0686817820564345 (avg_llrw: -3.9086817820564344) ; llwd: -1.569 ; arw: 1.692527287177426 ; brw: 6.183550573023805 ; ad: 2.2923999999999998 ; bd: 5.0903916
# <b>Floor sf</b>
# <style  type="text/css" >
# </style>
# <table id="T_68308c78_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_68308c78_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >9</th>
#         <td id="T_68308c78_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >0

#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row1_col5 {
#             background-color:  #343434;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row1_col6 {
#             background-color:  #313131;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row1_col7 {
#             background-color:  #2e2e2e;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row1_col8 {
#             background-color:  #2a2a2a;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row1_col9 {
#             background-color:  #272727;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col0 {
#             background-color:  #3a3a3a;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col1 {
#             background-color:  #3f3f3f;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col2 {
#             background-color:  #424242;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col3 {
#             background-color:  #424242;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col4 {
#             background-color:  #414141;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col5 {
#             background-color:  #3e3e3e;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col6 {
#             background-color:  #393939;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col7 {
#             background-color:  #343434;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col8 {
#             background-color:  #303030;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row2_col9 {
#             background-color:  #2b2b2b;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col0 {
#             background-color:  #474747;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col1 {
#             background-color:  #4d4d4d;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col2 {
#             background-color:  #515151;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col3 {
#             background-color:  #525252;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col4 {
#             background-color:  #505050;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col5 {
#             background-color:  #4b4b4b;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col6 {
#             background-color:  #444444;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col7 {
#             background-color:  #3d3d3d;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col8 {
#             background-color:  #363636;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row3_col9 {
#             background-color:  #2f2f2f;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col0 {
#             background-color:  #595959;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col1 {
#             background-color:  #616161;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col2 {
#             background-color:  #676767;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col3 {
#             background-color:  #696969;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col4 {
#             background-color:  #656565;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col5 {
#             background-color:  #5c5c5c;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col6 {
#             background-color:  #515151;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col7 {
#             background-color:  #474747;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col8 {
#             background-color:  #3d3d3d;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row4_col9 {
#             background-color:  #353535;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col0 {
#             background-color:  #6b6b6b;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col1 {
#             background-color:  #787878;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col2 {
#             background-color:  #848484;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col3 {
#             background-color:  #898989;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col4 {
#             background-color:  #838383;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col5 {
#             background-color:  #747474;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col6 {
#             background-color:  #626262;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col7 {
#             background-color:  #525252;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col8 {
#             background-color:  #454545;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row5_col9 {
#             background-color:  #3b3b3b;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col0 {
#             background-color:  #7e7e7e;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col1 {
#             background-color:  #949494;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col2 {
#             background-color:  #acacac;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col3 {
#             background-color:  #b7b7b7;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col4 {
#             background-color:  #aaaaaa;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col5 {
#             background-color:  #909090;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col6 {
#             background-color:  #747474;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col7 {
#             background-color:  #5d5d5d;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col8 {
#             background-color:  #4d4d4d;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row6_col9 {
#             background-color:  #444444;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row7_col0 {
#             background-color:  #8e8e8e;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row7_col1 {
#             background-color:  #aeaeae;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row7_col2 {
#             background-color:  #d9d9d9;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row7_col3 {
#             background-color:  #efefef;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row7_col4 {
#             background-color:  #d8d8d8;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row7_col5 {
#             background-color:  #ababab;
#         }    #T_688d8f86_f262_11e8_aaa3_e0cb4e922f83row7_col6 {
#             bac
# k: 6.604314879836959 ; q: 0.3356004995117118
# 1.0308442968251996

# %% [markdown]
# #### Avec des corrections
#
# - Efficient Radiosity Simulation using Perceptual Metrics and Parallel Processing, Simon Gibson, Thèse, (1999)
# - Tone Reproduction and Physically Based Spectral Rendering, K. Devlin, A. Chalmers, A. Wilkie & W. Purgathofer (2002)

# %%
# https://smartech.gatech.edu/bitstream/handle/1853/3699/91-13.pdf?sequence=1&isAllowed=y
# Tone Reproduction for Realistic Computer Generated Images, J.E. Tumblin, H.E. Rushmeier 1991
# http://apt.cs.manchester.ac.uk/ftp/pub/TR/UMCS-99-9-1.ps.Z lamberts -> cd/m^2 , coeff. (p57)
# cf. # Correction in http://doc.gold.ac.uk/~mas01kd/publications/egSTAR.pdf (4.2 Spatially uniform operators) (lamberts to cd/m^-2 ; fix 2nd coeff. for beta)
gamma = 2.2

avg_llrw = 0.
count = 0
for p in mesh.poly:
    if p.B != 0. and p.rho != -1. :
        avg_llrw += np.log10(p.B)
        count += 1

avg_llrw /= count
llwrw = avg_llrw + 0.84

ldmax = 150.

# display : (lamberts -> cd/m^2)
llwd = 1.929419

# Watch out: -0.218 / +0.218 ?
arw = 0.4*llwrw + 1.519
brw = -0.4*(llwrw*llwrw) - 0.218*llwrw + 6.1642

ad = 0.4*llwd + 1.519
bd = -0.4*(llwd*llwd) - 0.218*llwd + 6.1642

print(f"ldmax: {ldmax} ; llwrw: {llwrw} (avg_llrw: {avg_llrw}) ; llwd: {llwd} ; arw: {arw} ; brw: {brw} ; ad: {ad} ; bd: {bd}")

# Power law
# np.power( (1/ldmax)* np.power((B_floor[y, x]), arw/ad ) * np.power(10., (brw - bd)/ad), 1/gamma)
#  = k*(B_floor[y, x]*np.pi/10000)^q
k = np.power((1/ldmax), (1/gamma)) * np.power(10, (((brw - bd)/ad)*(1/gamma)))
q = (arw/ad) * 1/gamma


B_floor_sf = np.zeros([HEIGHT, WIDTH])
for y in range(HEIGHT):
    for x in range(WIDTH):
        #n = np.power( (1/ldmax)* np.power((B_floor[y, x]*np.pi/10000), arw/ad ) * np.power(10., (brw - bd)/ad), 1/gamma)
        n = k*np.power(B_floor[y, x], q)
        B_floor_sf[y, x] = n 

fdisplay(B_floor_sf, f"Floor sf")


data = np.copy(B_floor_sf)
lighting_color = np.zeros([HEIGHT, WIDTH])
convertRatioToRGB(data)
fakeDisplay("testing...", True)
k = np.power((1/ldmax), (1/gamma)) * np.power(10, (((brw - bd)/ad)*(1/gamma)))
q = (arw/ad) * 1/gamma
print(f"k: {k} ; q: {q}")
k*np.power(12.5688*np.pi/10000, q)
# Out:
# ldmax: 150.0 ; llwrw: 0.4341683452494336 (avg_llrw: -0.4058316547505664) ; llwd: 1.929419 ; arw: 1.6926673380997734 ; brw: 5.994150439928971 ; ad: 2.2907675999999997 ; bd: 4.2545235869755995
# <b>Floor sf</b>
# <style  type="text/css" >
# </style>
# <table id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >9</th>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col0" class="data row0 col0" >0.0866673</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col1" class="data row0 col1" >0.0911114</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col2" class="data row0 col2" >0.0938448</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col3" class="data row0 col3" >0.0946914</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col4" class="data row0 col4" >0.0936757</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col5" class="data row0 col5" >0.091006</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col6" class="data row0 col6" >0.0870408</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col7" class="data row0 col7" >0.0822034</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col8" class="data row0 col8" >0.0768893</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row0_col9" class="data row0 col9" >0.0714159</td>
#     </tr>    <tr>
#         <th id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83level0_row1" class="row_heading level0 row1" >8</th>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col0" class="data row1 col0" >0.100294</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col1" class="data row1 col1" >0.106736</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col2" class="data row1 col2" >0.110577</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col3" class="data row1 col3" >0.111646</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col4" class="data row1 col4" >0.109984</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col5" class="data row1 col5" >0.105934</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col6" class="data row1 col6" >0.100133</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col7" class="data row1 col7" >0.0933053</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col8" class="data row1 col8" >0.0860664</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row1_col9" class="data row1 col9" >0.0788409</td>
#     </tr>    <tr>
#         <th id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83level0_row2" class="row_heading level0 row2" >7</th>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row2_col0" class="data row2 col0" >0.118232</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row2_col1" class="data row2 col1" >0.127836</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row2_col2" class="data row2 col2" >0.133319</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row2_col3" class="data row2 col3" >0.134737</td>
#         <td id="T_68bb687a_f262_11e8_aaa3_e0cb4e922f83row2_

#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row3_col8 {
#             background-color:  #1b1b1b;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row3_col9 {
#             background-color:  #181818;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col0 {
#             background-color:  #2d2d2d;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col1 {
#             background-color:  #313131;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col2 {
#             background-color:  #353535;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col3 {
#             background-color:  #363636;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col4 {
#             background-color:  #343434;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col5 {
#             background-color:  #2f2f2f;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col6 {
#             background-color:  #2a2a2a;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col7 {
#             background-color:  #242424;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col8 {
#             background-color:  #1f1f1f;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row4_col9 {
#             background-color:  #1b1b1b;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col0 {
#             background-color:  #373737;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col1 {
#             background-color:  #3e3e3e;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col2 {
#             background-color:  #444444;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col3 {
#             background-color:  #464646;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col4 {
#             background-color:  #434343;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col5 {
#             background-color:  #3b3b3b;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col6 {
#             background-color:  #323232;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col7 {
#             background-color:  #2a2a2a;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col8 {
#             background-color:  #232323;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row5_col9 {
#             background-color:  #1e1e1e;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col0 {
#             background-color:  #414141;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col1 {
#             background-color:  #4c4c4c;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col2 {
#             background-color:  #585858;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col3 {
#             background-color:  #5e5e5e;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col4 {
#             background-color:  #585858;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col5 {
#             background-color:  #4a4a4a;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col6 {
#             background-color:  #3b3b3b;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col7 {
#             background-color:  #303030;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col8 {
#             background-color:  #272727;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row6_col9 {
#             background-color:  #232323;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row7_col0 {
#             background-color:  #494949;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row7_col1 {
#             background-color:  #5a5a5a;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row7_col2 {
#             background-color:  #6f6f6f;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row7_col3 {
#             background-color:  #7b7b7b;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row7_col4 {
#             background-color:  #6f6f6f;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row7_col5 {
#             background-color:  #585858;
#         }    #T_692fc4c2_f262_11e8_aaa3_e0cb4e922f83row7_col6 {
#             bac
# k: 0.22701418081032732 ; q: 0.33586743788012635
# 0.035381536322832294

# %% [markdown]
# - **TODO:** Vérifier le ^gamma
# - **TODO:** Attention à la somme pour la moyenne

# %% [markdown]
# ### A Contrast-Based Scalefactor for Luminance Display, G. Ward
#
# #### Version originale 1994
#
# - (L*sf)^1/gamma, ajouté d'après Efficient Radiosity Simulation using Perceptual Metrics and Parallel Processing, S. Gibson

# %%
# http://eta-publications.lbl.gov/sites/default/files/lbl-35252.pdf
# A Contrast-based scalefactor for luminance display, G. Ward 1994
lwa = 0.
count = 0
for p in mesh.poly:
    if p.B != 0. and p.rho != -1. :
        lwa += np.log10(p.B)
        count += 1
lwa /= count
lwa += 0.84
lwa = np.power(10, lwa)

print(f"lwa = {lwa}")
ldmax = 150.

gamma = 2.2
sf = (1/ldmax) * np.power((1.219 + np.power(ldmax/2., 0.4)) / (1.219 + np.power(lwa, 0.4)), 2.5)

B_floor_sf = np.zeros([HEIGHT, WIDTH])
for y in range(HEIGHT):
    for x in range(WIDTH):
        B_floor_sf[y, x] = np.power(B_floor[y, x] * sf, 1/gamma)

fdisplay(B_floor_sf, "Floor sf")
data = np.copy(B_floor_sf)
convertRatioToRGB(data)
fakeDisplay("testing...", True)
print(f"lwa: {lwa} ; sf: {sf}")
# Out:
# lwa = 2.7174924442952726
# <b>Floor sf</b>
# <style  type="text/css" >
# </style>
# <table id="T_69679e06_f262_11e8_aaa3_e0cb4e922f83" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#         <th class="col_heading level0 col4" >4</th>
#         <th class="col_heading level0 col5" >5</th>
#         <th class="col_heading level0 col6" >6</th>
#         <th class="col_heading level0 col7" >7</th>
#         <th class="col_heading level0 col8" >8</th>
#         <th class="col_heading level0 col9" >9</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_69679e06_f262_11e8_aaa3_e0cb4e922f83level0_row0" class="row_heading level0 row0" >9</th>
#         <td id="T_69679e06_f262_11e8_aaa3_e0cb4e922f83row0_

#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col1 {
#             background-color:  #151515;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col2 {
#             background-color:  #161616;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col3 {
#             background-color:  #161616;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col4 {
#             background-color:  #161616;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col5 {
#             background-color:  #151515;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col6 {
#             background-color:  #141414;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col7 {
#             background-color:  #121212;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col8 {
#             background-color:  #111111;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row0_col9 {
#             background-color:  #0f0f0f;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col0 {
#             background-color:  #181818;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col1 {
#             background-color:  #1a1a1a;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col2 {
#             background-color:  #1c1c1c;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col3 {
#             background-color:  #1c1c1c;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col4 {
#             background-color:  #1c1c1c;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col5 {
#             background-color:  #1a1a1a;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col6 {
#             background-color:  #181818;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col7 {
#             background-color:  #161616;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col8 {
#             background-color:  #141414;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row1_col9 {
#             background-color:  #111111;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col0 {
#             background-color:  #1e1e1e;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col1 {
#             background-color:  #222222;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col2 {
#             background-color:  #242424;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col3 {
#             background-color:  #242424;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col4 {
#             background-color:  #232323;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col5 {
#             background-color:  #212121;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col6 {
#             background-color:  #1e1e1e;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col7 {
#             background-color:  #1b1b1b;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col8 {
#             background-color:  #171717;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row2_col9 {
#             background-color:  #141414;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col0 {
#             background-color:  #282828;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col1 {
#             background-color:  #2d2d2d;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col2 {
#             background-color:  #303030;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col3 {
#             background-color:  #313131;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col4 {
#             background-color:  #2f2f2f;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col5 {
#             background-color:  #2b2b2b;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col6 {
#             background-color:  #262626;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col7 {
#             background-color:  #202020;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col8 {
#             background-color:  #1b1b1b;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row3_col9 {
#             background-color:  #171717;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col0 {
#             background-color:  #363636;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col1 {
#             background-color:  #3d3d3d;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col2 {
#             background-color:  #424242;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col3 {
#             background-color:  #444444;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col4 {
#             background-color:  #414141;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col5 {
#             background-color:  #393939;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col6 {
#             background-color:  #303030;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col7 {
#             background-color:  #282828;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col8 {
#             background-color:  #212121;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row4_col9 {
#             background-color:  #1b1b1b;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col0 {
#             background-color:  #464646;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col1 {
#             background-color:  #525252;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col2 {
#             background-color:  #5e5e5e;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col3 {
#             background-color:  #626262;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col4 {
#             background-color:  #5c5c5c;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col5 {
#             background-color:  #4e4e4e;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col6 {
#             background-color:  #3e3e3e;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col7 {
#             background-color:  #313131;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col8 {
#             background-color:  #272727;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row5_col9 {
#             background-color:  #1f1f1f;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col0 {
#             background-color:  #585858;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col1 {
#             background-color:  #6c6c6c;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col2 {
#             background-color:  #858585;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col3 {
#             background-color:  #919191;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col4 {
#             background-color:  #848484;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col5 {
#             background-color:  #686868;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col6 {
#             background-color:  #4e4e4e;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col7 {
#             background-color:  #3a3a3a;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col8 {
#             background-color:  #2d2d2d;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row6_col9 {
#             background-color:  #262626;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row7_col0 {
#             background-color:  #676767;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row7_col1 {
#             background-color:  #888888;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row7_col2 {
#             background-color:  #b6b6b6;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row7_col3 {
#             background-color:  #d0d0d0;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row7_col4 {
#             background-color:  #b5b5b5;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row7_col5 {
#             background-color:  #848484;
#         }    #T_69ed99fc_f262_11e8_aaa3_e0cb4e922f83row7_col6 {
#             bac
# lwa: 2.7174924442952726 ; sf: 0.06749912921610918

# %% [markdown]
# ## Et maintenant ?
